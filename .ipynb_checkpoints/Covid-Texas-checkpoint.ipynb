# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from time import sleep
from datetime import datetime
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import time
import json
import os
import shutil

# %%
# Path to chromedriver.exe
executable_path = {'executable_path':'C:/Users/zacha/AppData/Local/bin/chromedriver.exe'}

# Open the Splinter Browswer
browser = Browser('chrome', **executable_path)

# %%
# URL to find information on Coronavirus
url1 = "https://txdshs.maps.arcgis.com/apps/opsdashboard/index.html#/ed483ecd702b4298ab01e8b9cafc8b83"

url2 = "https://dshs.texas.gov/coronavirus/"

url3 = "http://publichealth.harriscountytx.gov/Resources/2019-Novel-Coronavirus/Harris-County-COVID-19-Confirmed-Cases"

url4 = "https://www.khou.com/section/news/health/coronavirus"

# %%
# Visiting the url 
browser.visit(url1)

# %%
time.sleep(7)# Creating the Beautiful soup for URL
html = browser.html
soup = bs(html, 'html.parser')

# %%
# All the Texas counties
# counties = soup.find('nav', attrs={'class':'feature-list'})

# getting all the spans with the information for each Texas county
# rows = counties.find_all('span')

# %%
# counter = 0

# county = []
# cases = []

# for row in rows:
#     try:
#         print(rows[counter].text.strip().split('\n'))
#         county.append(rows[counter].text.strip().split('\n')[0])
#         cases.append(rows[counter].text.strip().split('\n')[1])
#         counter = counter + 3
        
#     except:
#         print('failure')

# %%
# df = pd.DataFrame(list(zip(county, cases)), columns =['Texas_County', 'COVID_19_Cases'])
# df

# %%
# Droping the word 'County'
# df['Texas_County'] = df['Texas_County'].apply(lambda x : x.split(' County')[0])

# %%
# Revise? 
reported_cases = soup.find_all('text')[6].text
reported_cases
# Out:
# '2,877'

# %%
deaths = soup.find_all('text')[8].text
deaths
# Out:
# '38'

# %%
df_stats = pd.DataFrame({'Cases':[reported_cases], 'Deaths':[deaths]})
df_stats.to_csv('static/csv/stats.csv', index=False)

# %%
# Getting Total Cases and Deaths 
browser.visit(url2)

# %%
browser.find_by_text('Accessible version (Excel)').click()
time.sleep(5)

# %%
source = 'C:/Users/zacha/Downloads/'
destination = 'C:/Users/zacha/Documents/COVID-19/'
filename = 'CaseCountData.xlsx'

# %%
shutil.move(os.path.join(source, filename), os.path.join(destination, filename))
# Out:
# 'C:/Users/zacha/Documents/COVID-19/CaseCountData.xlsx'

# %%
# dest = shutil.move(source, destination, )

# %%
df = pd.read_excel('CaseCountData.xlsx', header=1).dropna()
df.sort_values(by=['Positive'], ascending=False, inplace=True)
df['County'] = df.apply(lambda x: x['County'].rstrip(), axis=1)
df
# Out:
#        No.        County  Positive  Fatalities
# 47    48.0        Harris       445           3
# 24    25.0        Dallas       439           9
# 102  103.0        Travis       179           1
# 27    28.0        Denton       148           2
# 5      6.0         Bexar       140           5
# ..     ...           ...       ...         ...
# 48    49.0      Harrison         1           0
# 45    46.0          Hale         1           0
# 92    93.0   San Jacinto         1           0
# 93    94.0  San Patricio         1           0
# 117  118.0         Young         1           0
#
# [118 rows x 4 columns]

# %%
browser.visit(url3)

# %%
harris_table = browser.find_by_id('covidtable')

# %%
html_harris = browser.html
harris_soup = bs(html_harris, 'html.parser')

# %%
harris_data = []
table = harris_soup.find('table', attrs={'id':'covidtable'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    harris_data.append([ele for ele in cols if ele]) # Get rid of empty values

# %%
columns = ['Patient', 'Sex', 'Age_Range', 'Location','Exposure', 'Status']

# %%
harris_data = harris_data[1:]

# %%
harris_df = pd.DataFrame(harris_data, columns=columns)

# %%
harris_df.sort_values(by=['Age_Range'], inplace=True)

# %%
harris_df
# Out:
#     Patient     Sex Age_Range Location                   Exposure    Status
# 172     173  Female     0 - 9       NW  Possible Exposure to Case    Active
# 43       44    Male     0 - 9       NW  Possible Exposure to Case    Active
# 45       46  Female     0 - 9       NW  Possible Exposure to Case    Active
# 185     186  Female     0 - 9       SE  Possible Exposure to Case    Active
# 169     170    Male   10 - 19       NW  Possible Exposure to Case    Active
# ..      ...     ...       ...      ...                        ...       ...
# 158     159  Female       80+       NW          History of Travel    Active
# 15       16    Male       80+       NW          No Known Exposure  Deceased
# 204     205    Male       80+       SE      Investigation Pending    Active
# 193     194  Female       80+       SE          No Known Exposure    Active
# 154     155  Female       80+       SE      Investigation Pending    Active
#
# [240 rows x 6 columns]

# %%
harris_df.to_csv('static/csv/harris_stats.csv', index=False, header=True)

# %%
harris_df.head()
# Out:
#     Patient     Sex Age_Range Location                   Exposure  Status
# 172     173  Female     0 - 9       NW  Possible Exposure to Case  Active
# 43       44    Male     0 - 9       NW  Possible Exposure to Case  Active
# 45       46  Female     0 - 9       NW  Possible Exposure to Case  Active
# 185     186  Female     0 - 9       SE  Possible Exposure to Case  Active
# 169     170    Male   10 - 19       NW  Possible Exposure to Case  Active

# %%
All_Tex_Counties_df = pd.read_csv('static/csv/Texas_Counties.csv')
All_Tex_Counties_df.head()
# Out:
#      X (Lat)   Y (Long)    CNTY_NM  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# 0 -97.492799  29.456415   Gonzales        90  48177    2.124911    0.257805
# 1 -98.697292  27.043405   Jim Hogg       125  48247    2.271751    0.267624
# 2 -97.681378  26.924094     Kenedy        66  48261    5.067864    0.389397
# 3 -96.965687  30.310651        Lee       144  48287    2.213853    0.153990
# 4 -95.853568  32.211881  Henderson       108  48213    3.152909    0.235056
#
#            County Location
# 0  (-97.492799, 29.456415)
# 1  (-98.697292, 27.043405)
# 2  (-97.681378, 26.924094)
# 3  (-96.965687, 30.310651)
# 4  (-95.853568, 32.211881)

# %%
All_Tex_Counties = All_Tex_Counties_df['CNTY_NM'].tolist()

# %%
df_counties = df['County'].tolist()

# %%
Counties_with_Cases = []

for i in df_counties:
    
    if i.rstrip() in All_Tex_Counties:
        Counties_with_Cases.append(i.rstrip())
        print(f'{i}---found')
        
    elif i == 'DeWitt':
        Counties_with_Cases.append('De Witt')
        print(f'{i}---found')
    else:
        print(f'Houston we have a problem: {i}')
# Out:
# Harris---found
# Dallas---found
# Travis---found
# Denton---found
# Bexar---found
# Tarrant---found
# Collin---found
# Fort Bend---found
# Montgomery---found
# Brazoria---found
# Galveston---found
# Lubbock---found
# Brazos---found
# Williamson---found
# McLennan---found
# El Paso---found
# Smith---found
# Bell---found
# Hidalgo---found
# Wichita---found
# Webb---found
# Nueces---found
# Cameron---found
# Jefferson---found
# Hays---found
# Ellis---found
# Matagorda---found
# Midland---found
# Guadalupe---found
# Hardin---found
# Comal---found
# Johnson---found
# Castro---found
# Hockley---found
# Taylor---found
# Kendall---found
# Wharton---found
# Val Verde---found
# Washington---found
# Bastrop---found
# Potter---found
# Parker---found
# Gregg---found
# Rockwall---found
# Lamar---found
# Medina---found
# Randall---found
# Angelina---found
# Rusk---found
# Walker---found
# Bowie---found
# Brown---found
# Calhoun---found
# Chambers---found
# Waller---found
# Grayson---found
# Tom Green---found
# Victoria---found
# DeWitt---found
# Eastland---found
# Terry---found
# Uvalde---found
# Nacogdoches---found
# Robertson---found
# Willacy---found
# Milam---found
# Starr---found
# Wilson---found
# Oldham---found
# Kaufman---found
# Karnes---found
# Austin---found
# Llano---found
# Grimes---found
# Liberty---found
# Cass---found
# Atascosa---found
# Hood---found
# Deaf Smith---found
# Van Zandt---found
# Fayette---found
# Fannin---found
# Falls---found
# Erath---found
# Upshur---found
# Ector---found
# Martin---found
# Dawson---found
# Crane---found
# Swisher---found
# Coryell---found
# Cherokee---found
# Caldwell---found
# Burnet---found
# Burleson---found
# Blanco---found
# Franklin---found
# Shelby---found
# Gaines---found
# Lynn---found
# Maverick---found
# Limestone---found
# Lavaca---found
# Montague---found
# Lamb---found
# Morris---found
# Kleberg---found
# Navarro---found
# Orange---found
# Jackson---found
# Polk---found
# Hunt---found
# Hopkins---found
# Harrison---found
# Hale---found
# San Jacinto---found
# San Patricio---found
# Young---found

# %%
All_Tex_Counties_df = All_Tex_Counties_df.set_index('CNTY_NM')

# %%
Geo_df = All_Tex_Counties_df.loc[Counties_with_Cases]
Geo_df.head()
# Out:
#            X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# CNTY_NM
# Harris  -95.397821  29.859671       102  48201    7.731110    0.422798
# Dallas  -96.777819  32.766537        57  48113    1.907782    0.226421
# Travis  -97.781947  30.334233       227  48453    2.458272    0.248996
# Denton  -97.116812  33.205574        61  48121    1.969324    0.238359
# Bexar   -98.519663  29.448845        15  48029    2.729791    0.302846
#
#                  County Location
# CNTY_NM
# Harris   (-95.397821, 29.859671)
# Dallas   (-96.777819, 32.766537)
# Travis   (-97.781947, 30.334233)
# Denton   (-97.116812, 33.205574)
# Bexar    (-98.519663, 29.448845)

# %%
Geo_df = Geo_df.reset_index()
Geo_df = Geo_df.rename(columns={"CNTY_NM": "County"})
Geo_df
# Out:
#            County     X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  \
# 0          Harris  -95.397821  29.859671       102  48201    7.731110
# 1          Dallas  -96.777819  32.766537        57  48113    1.907782
# 2          Travis  -97.781947  30.334233       227  48453    2.458272
# 3          Denton  -97.116812  33.205574        61  48121    1.969324
# 4           Bexar  -98.519663  29.448845        15  48029    2.729791
# ..            ...         ...        ...       ...    ...         ...
# 113      Harrison  -94.371557  32.548149       103  48203    2.563571
# 114          Hale -101.826908  34.070518        96  48189    2.018358
# 115   San Jacinto  -95.166833  30.579489       204  48407    2.203357
# 116  San Patricio  -97.518599  28.009222       205  48409    3.462106
# 117         Young  -98.687814  33.176708       252  48503    1.941651
#
#      Shape_Area           County Location
# 0      0.422798   (-95.397821, 29.859671)
# 1      0.226421   (-96.777819, 32.766537)
# 2      0.248996   (-97.781947, 30.334233)
# 3      0.238359   (-97.116812, 33.205574)
# 4      0.302846   (-98.519663, 29.448845)
# ..          ...                       ...
# 113    0.227726   (-94.371557, 32.548149)
# 114    0.254142  (-101.826908, 34.070518)
# 115    0.153019   (-95.166833, 30.579489)
# 116    0.167654   (-97.518599, 28.009222)
# 117    0.233022   (-98.687814, 33.176708)
#
# [118 rows x 8 columns]

# %%
result = pd.merge(df, Geo_df, on='County')
result = result.rename(columns={'X (Lat)':'long', 'Y (Long)':'lat'})

result.head()
# Out:
#      No.  County  Positive  Fatalities       long        lat  CNTY_NBR   FIPS  \
# 0   48.0  Harris       445           3 -95.397821  29.859671       102  48201
# 1   25.0  Dallas       439           9 -96.777819  32.766537        57  48113
# 2  103.0  Travis       179           1 -97.781947  30.334233       227  48453
# 3   28.0  Denton       148           2 -97.116812  33.205574        61  48121
# 4    6.0   Bexar       140           5 -98.519663  29.448845        15  48029
#
#    Shape_Leng  Shape_Area          County Location
# 0    7.731110    0.422798  (-95.397821, 29.859671)
# 1    1.907782    0.226421  (-96.777819, 32.766537)
# 2    2.458272    0.248996  (-97.781947, 30.334233)
# 3    1.969324    0.238359  (-97.116812, 33.205574)
# 4    2.729791    0.302846  (-98.519663, 29.448845)

# %%
result = result[['County', 'Positive', 'Fatalities', 'lat', 'long']]
result
# Out:
#            County  Positive  Fatalities        lat        long
# 0          Harris       445           3  29.859671  -95.397821
# 1          Dallas       439           9  32.766537  -96.777819
# 2          Travis       179           1  30.334233  -97.781947
# 3          Denton       148           2  33.205574  -97.116812
# 4           Bexar       140           5  29.448845  -98.519663
# ..            ...       ...         ...        ...         ...
# 112      Harrison         1           0  32.548149  -94.371557
# 113          Hale         1           0  34.070518 -101.826908
# 114   San Jacinto         1           0  30.579489  -95.166833
# 115  San Patricio         1           0  28.009222  -97.518599
# 116         Young         1           0  33.176708  -98.687814
#
# [117 rows x 5 columns]

# %%
def df_to_geojson(df, properties, lat='lat', lon='long'):
    prefix = 'var' + ' data' + ' = '
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point','coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lat],row[lon]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols = ['County', 'Positive', 'Fatalities']
javascript_file = df_to_geojson(result, cols)
# {'type': 'FeatureCollection', 'features': [{'geometry': {'type': 'Point', 'coordinates': [-70.5867, -29.9953, 760]}, 'type': 'Feature', 'properties': {'name': 'A', 'description': 'Place a'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.4933, -30.1217, 1250]}, 'type': 'Feature', 'properties': {'name': 'B', 'description': 'Place b'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.5008, -30.0953, 1185]}, 'type': 'Feature', 'properties': {'name': 'C', 'description': 'Place c'}}]}

# %%
with open('static/js/map.json','w') as f:
    json.dump(javascript_file, f, indent=4, sort_keys=False)

# %%
browser.visit(url4)

# %%
headlines_harris = browser.html
headline_soup = bs(headlines_harris, 'html.parser')

# %%
# lis = headline_soup.find_all('li', class_="headline-list-with-abstract__item")
links = headline_soup.find_all('div', class_="headline-list-with-abstract__headline")

titles = []
hrefs = []

# %%
recent = headline_soup.find_all('div', class_="story-snapshot-with-abstract__headline")[0]

# %%
recent
# Out:
# <div class="story-snapshot-with-abstract__headline">
# <a class="story-snapshot-with-abstract__link" data-tracking="story-snapshot-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-updates-houston-live-log-march-30/285-b2f89f1b-939c-4a9e-8a03-f5b42d8ef51c">
# <div class="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180" style="overflow-wrap: break-word;">
#                         Coronavirus updates: Harris County Tax Office offers 3-month break in delinquent property tax payments
#                     </div>
# <div class="story-snapshot-with-abstract__mobile-title dot-ellipsis dot-height-135" style="overflow-wrap: break-word;">
#                         Coronavirus updates: Harris County Tax Office offers 3-month break in delinquent property tax payments
#                     </div>
# </a>
# </div>

# %%
recent_title = recent.find('div', class_="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180").text.strip()
recent_title
# Out:
# 'Coronavirus updates: Harris County Tax Office offers 3-month break in delinquent property tax payments'

# %%
titles.append(recent_title)
hrefs.append('https://www.khou.com' + recent.a['href'])

# %%
links
# Out:
# [<div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/money/harris-county-tax-office-offers-3-month-break-in-delinquent-property-tax-payments/285-976604ce-e2a1-4519-9428-fbb950191402">
#                      Harris County Tax Office offers 3-month break in delinquent property tax payments
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-live-blog-updates-march-30-2020/285-5691314b-0899-4a51-a16d-a8cbdff95938">
#                      Coronavirus live updates: Navy hospital ship arrives in NYC, Tokyo Olympics set new dates
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/houston-coronavirus-testing/285-c95ce8c4-f876-4d6c-8645-4922578617df">
#                      Here's how Houston-area residents can get tested for coronavirus
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/houston-area-coronavirus-cases/285-192b8879-08b6-4ec0-8a0f-a0487ead1453">
#                      Map: Keeping track of Houston-area coronavirus cases
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/syndication/heartthreads/watch-this-high-school-mariachi-bands-impressive-virtual-practice/285-67d9124f-a1bd-48a8-ad1d-0a18f65e5916">
#                      VIDEO: Fifteen high schoolers make mariachi magic in virtual rehearsal
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/blissful-ignorance-submariners-likely-unaware-of-pandemic/285-f415060e-995f-445b-85b0-79899cea1437">
#                      Blissful ignorance? Submariners likely unaware of pandemic
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/how-does-the-stimulus-package-help-small-businesses/285-8f5ffe43-e9c6-4c80-b986-fa218741fe52">
#                      $350 billion set aside for 'Paycheck Protection Program' - any small company can apply
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/what-does-shelter-in-place-mean-these-are-the-states-that-want-citizens-to-stay-home/285-9f19139a-2f1d-4c8b-9343-2c8fd42b2208">
#                      These states have issued stay-at-home orders. What does that mean?
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/hydroxychloroquine-chloroquine-fda-emergency-authorization/285-d7d1eade-e1cb-42d8-b7cf-4f9bba6fe8af">
#                      FDA authorizes emergency use of anti-malarial drugs touted by Trump on COVID-19 patients
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/houston-methodist-testing-potential-treatment-that-could-be-key-to-fighting-covid-19/285-f46a5595-7e7e-4af7-a665-360ba437f8d3">
#                      Houston Methodist testing COVID-19 treatment that uses survivors' blood plasma to fight the infection
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/nation-world/dutch-museum-says-van-gogh-painting-stolen-in-overnight-raid/285-d776c528-1f8f-4171-86b8-d6fb2ea8fe98">
#                      Dutch museum closed due to COVID-19 says van Gogh painting was stolen
#                  </a>
#  </div>]

# %%
for article in links:
    
    try:
        
        title = article.find('a', class_="headline-list-with-abstract__link").text
        
        link = article.a['href']
        
        if (title and link):
            
            
            print('-------------')
            print(title)
            print(link)
            titles.append(title.strip())
            hrefs.append('https://www.khou.com' + link)
            
    except:
        print('no')
# Out:
# -------------
#
#                     Harris County Tax Office offers 3-month break in delinquent property tax payments
#
# /article/money/harris-county-tax-office-offers-3-month-break-in-delinquent-property-tax-payments/285-976604ce-e2a1-4519-9428-fbb950191402
# -------------
#
#                     Coronavirus live updates: Navy hospital ship arrives in NYC, Tokyo Olympics set new dates
#
# /article/news/health/coronavirus/coronavirus-live-blog-updates-march-30-2020/285-5691314b-0899-4a51-a16d-a8cbdff95938
# -------------
#
#                     Here's how Houston-area residents can get tested for coronavirus
#
# /article/news/health/coronavirus/houston-coronavirus-testing/285-c95ce8c4-f876-4d6c-8645-4922578617df
# -------------
#
#                     Map: Keeping track of Houston-area coronavirus cases
#
# /article/news/health/coronavirus/houston-area-coronavirus-cases/285-192b8879-08b6-4ec0-8a0f-a0487ead1453
# -------------
#
#                     VIDEO: Fifteen high schoolers make mariachi magic in virtual rehearsal
#
# /article/syndication/heartthreads/watch-this-high-school-mariachi-bands-impressive-virtual-practice/285-67d9124f-a1bd-48a8-ad1d-0a18f65e5916
# -------------
#
#                     Blissful ignorance? Submariners likely unaware of pandemic
#
# /article/news/health/coronavirus/blissful-ignorance-submariners-likely-unaware-of-pandemic/285-f415060e-995f-445b-85b0-79899cea1437
# -------------
#
#                     $350 billion set aside for 'Paycheck Protection Program' - any small company can apply
#
# /article/news/health/coronavirus/how-does-the-stimulus-package-help-small-businesses/285-8f5ffe43-e9c6-4c80-b986-fa218741fe52
# -------------
#
#                     These states have issued stay-at-home orders. What does that mean?
#
# /article/news/health/coronavirus/what-does-shelter-in-place-mean-these-are-the-states-that-want-citizens-to-stay-home/285-9f19139a-2f1d-4c8b-9343-2c8fd42b2208
# -------------
#
#                     FDA authorizes emergency use of anti-malarial drugs touted by Trump on COVID-19 patients
#
# /article/news/health/coronavirus/hydroxychloroquine-chloroquine-fda-emergency-authorization/285-d7d1eade-e1cb-42d8-b7cf-4f9bba6fe8af
# -------------
#
#                     Houston Methodist testing COVID-19 treatment that uses survivors' blood plasma to fight the infection
#
# /article/news/health/coronavirus/houston-methodist-testing-potential-treatment-that-could-be-key-to-fighting-covid-19/285-f46a5595-7e7e-4af7-a665-360ba437f8d3
# -------------
#
#                     Dutch museum closed due to COVID-19 says van Gogh painting was stolen
#
# /article/news/nation-world/dutch-museum-says-van-gogh-painting-stolen-in-overnight-raid/285-d776c528-1f8f-4171-86b8-d6fb2ea8fe98

# %%
latest_headlines_df = pd.DataFrame(list(zip(titles, hrefs)), columns =['Headline', 'link'])

# %%
latest_headlines_df
# Out:
#                                              Headline  \
# 0   Coronavirus updates: Harris County Tax Office ...
# 1   Harris County Tax Office offers 3-month break ...
# 2   Coronavirus live updates: Navy hospital ship a...
# 3   Here's how Houston-area residents can get test...
# 4   Map: Keeping track of Houston-area coronavirus...
# 5   VIDEO: Fifteen high schoolers make mariachi ma...
# 6   Blissful ignorance? Submariners likely unaware...
# 7   $350 billion set aside for 'Paycheck Protectio...
# 8   These states have issued stay-at-home orders. ...
# 9   FDA authorizes emergency use of anti-malarial ...
# 10  Houston Methodist testing COVID-19 treatment t...
# 11  Dutch museum closed due to COVID-19 says van G...
#
#                                                  link
# 0   https://www.khou.com/article/news/health/coron...
# 1   https://www.khou.com/article/money/harris-coun...
# 2   https://www.khou.com/article/news/health/coron...
# 3   https://www.khou.com/article/news/health/coron...
# 4   https://www.khou.com/article/news/health/coron...
# 5   https://www.khou.com/article/syndication/heart...
# 6   https://www.khou.com/article/news/health/coron...
# 7   https://www.khou.com/article/news/health/coron...
# 8   https://www.khou.com/article/news/health/coron...
# 9   https://www.khou.com/article/news/health/coron...
# 10  https://www.khou.com/article/news/health/coron...
# 11  https://www.khou.com/article/news/nation-world...

# %%
latest_headlines_df.to_csv('static/csv/headlines.csv', index=False, header=True)

# %%
browser.quit()
