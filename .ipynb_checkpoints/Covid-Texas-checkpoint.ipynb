# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from time import sleep
from datetime import datetime
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import time
import json
import os
import shutil

# %%
# Path to chromedriver.exe
executable_path = {'executable_path':'C:/Users/zacha/AppData/Local/bin/chromedriver.exe'}

# Open the Splinter Browswer
browser = Browser('chrome', **executable_path)

# %%
# URL to find information on Coronavirus
url1 = "https://txdshs.maps.arcgis.com/apps/opsdashboard/index.html#/ed483ecd702b4298ab01e8b9cafc8b83"

url2 = "https://dshs.texas.gov/coronavirus/"

# url3 = "http://publichealth.harriscountytx.gov/Resources/2019-Novel-Coronavirus/Harris-County-COVID-19-Confirmed-Cases"

url4 = "https://www.khou.com/section/news/health/coronavirus"

# %%
# Visiting the url 
browser.visit(url1)

# %%
time.sleep(7)# Creating the Beautiful soup for URL
html = browser.html
soup = bs(html, 'html.parser')

# %%
# Revise? 
reported_cases = soup.find_all('text')[9].text
reported_cases
# Out:
# '11,671'

# %%
deaths = soup.find_all('text')[11].text
deaths
# Out:
# '226'

# %%
df_stats = pd.DataFrame({'Cases':[reported_cases], 'Deaths':[deaths]})
df_stats.to_csv('static/csv/stats.csv', index=False)

# %%
# Getting Total Cases and Deaths 
browser.visit(url2)

# %%
browser.find_by_text('Accessible version').click()
time.sleep(5)

# %%
source = 'C:/Users/zacha/Downloads/'
destination = 'C:/Users/zacha/Documents/COVID-19/'
filename = 'CaseCountData.xlsx'

# %%
shutil.move(os.path.join(source, filename), os.path.join(destination, filename))
# Out:
# 'C:/Users/zacha/Documents/COVID-19/CaseCountData.xlsx'

# %%
# dest = shutil.move(source, destination, )

# %%
df = pd.read_excel('CaseCountData.xlsx', header=1).dropna()
df.sort_values(by=['Cases'], ascending=False, inplace=True)
df['County'] = df.apply(lambda x: x['County'].rstrip(), axis=1)
df.to_csv('static/csv/CaseCountData.csv', index=False, header=True)

df
# Out:
#        No.     County  Cases  Fatalities
# 72    73.0     Harris   3047          34
# 38    39.0     Dallas   1432          22
# 154  155.0     Travis    642           7
# 149  150.0    Tarrant    637          20
# 10    11.0      Bexar    615          22
# ..     ...        ...    ...         ...
# 69    70.0   Hamilton      1           0
# 60    61.0  Gillespie      1           0
# 58    59.0     Gaines      1           0
# 57    58.0       Frio      1           0
# 70    71.0   Hansford      1           0
#
# [176 rows x 4 columns]

# %%
df
# Out:
#        No.     County  Cases  Fatalities
# 72    73.0     Harris   3047          34
# 38    39.0     Dallas   1432          22
# 154  155.0     Travis    642           7
# 149  150.0    Tarrant    637          20
# 10    11.0      Bexar    615          22
# ..     ...        ...    ...         ...
# 69    70.0   Hamilton      1           0
# 60    61.0  Gillespie      1           0
# 58    59.0     Gaines      1           0
# 57    58.0       Frio      1           0
# 70    71.0   Hansford      1           0
#
# [176 rows x 4 columns]

# %%
# browser.visit(url3)

# %%
# harris_table = browser.find_by_id('covidtable')

# %%
# html_harris = browser.html
# harris_soup = bs(html_harris, 'html.parser')

# %%
# harris_data = []
# table = harris_soup.find('table', attrs={'id':'covidtable'})
# table_body = table.find('tbody')

# rows = table_body.find_all('tr')
# for row in rows:
#     cols = row.find_all('td')
#     cols = [ele.text.strip() for ele in cols]
#     harris_data.append([ele for ele in cols if ele])

# %%
# columns = ['Patient', 'Sex', 'Age_Range', 'Location','Exposure', 'Status']

# %%
# harris_data = harris_data[1:]

# %%
# harris_df = pd.DataFrame(harris_data, columns=columns)

# %%
# harris_df.sort_values(by=['Age_Range'], inplace=True)

# %%
# harris_df.to_csv('static/csv/harris_stats.csv', index=False, header=True)

# %%
# harris_df.head()

# %%
All_Tex_Counties_df = pd.read_csv('static/csv/Texas_Counties.csv')
All_Tex_Counties_df.head()
# Out:
#      X (Lat)   Y (Long)    CNTY_NM  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# 0 -97.492799  29.456415   Gonzales        90  48177    2.124911    0.257805
# 1 -98.697292  27.043405   Jim Hogg       125  48247    2.271751    0.267624
# 2 -97.681378  26.924094     Kenedy        66  48261    5.067864    0.389397
# 3 -96.965687  30.310651        Lee       144  48287    2.213853    0.153990
# 4 -95.853568  32.211881  Henderson       108  48213    3.152909    0.235056
#
#            County Location
# 0  (-97.492799, 29.456415)
# 1  (-98.697292, 27.043405)
# 2  (-97.681378, 26.924094)
# 3  (-96.965687, 30.310651)
# 4  (-95.853568, 32.211881)

# %%
All_Tex_Counties = All_Tex_Counties_df['CNTY_NM'].tolist()

# %%
df_counties = df['County'].tolist()

# %%
Counties_with_Cases = []

for i in df_counties:
    
    if i.rstrip() in All_Tex_Counties:
        Counties_with_Cases.append(i.rstrip())
        print(f'{i}---found')
        
    elif i == 'DeWitt':
        Counties_with_Cases.append('De Witt')
        print(f'{i}---found')
    else:
        print(f'Houston we have a problem: {i}')
# Out:
# Harris---found
# Dallas---found
# Travis---found
# Tarrant---found
# Bexar---found
# Fort Bend---found
# Denton---found
# Collin---found
# Galveston---found
# Lubbock---found
# Montgomery---found
# El Paso---found
# Brazoria---found
# Webb---found
# Cameron---found
# Hidalgo---found
# Brazos---found
# Williamson---found
# Jefferson---found
# Smith---found
# Bell---found
# Hays---found
# Victoria---found
# Nueces---found
# McLennan---found
# Potter---found
# Ellis---found
# Randall---found
# Wichita---found
# Taylor---found
# Guadalupe---found
# Hardin---found
# Ector---found
# Matagorda---found
# Gregg---found
# Washington---found
# Comal---found
# Tom Green---found
# Shelby---found
# Midland---found
# Orange---found
# Nacogdoches---found
# Bowie---found
# Johnson---found
# Chambers---found
# Kaufman---found
# Moore---found
# Donley---found
# Wharton---found
# Bastrop---found
# Coryell---found
# Grayson---found
# Rockwall---found
# Liberty---found
# Angelina---found
# Hunt---found
# Calhoun---found
# Rusk---found
# Walker---found
# Waller---found
# Harrison---found
# Hockley---found
# Gray---found
# Hood---found
# Parker---found
# Andrews---found
# Navarro---found
# Medina---found
# Erath---found
# Van Zandt---found
# Kendall---found
# Wilson---found
# Castro---found
# Panola---found
# San Augustine---found
# Limestone---found
# Hale---found
# Fayette---found
# Lamar---found
# Maverick---found
# Austin---found
# DeWitt---found
# Brown---found
# Henderson---found
# Polk---found
# Hill---found
# Milam---found
# Uvalde---found
# Starr---found
# San Patricio---found
# Deaf Smith---found
# Atascosa---found
# Burleson---found
# Val Verde---found
# Burnet---found
# Cherokee---found
# Upshur---found
# Terry---found
# Grimes---found
# Colorado---found
# Titus---found
# Caldwell---found
# Fannin---found
# Willacy---found
# Dawson---found
# Lynn---found
# Wood---found
# Cass---found
# Jackson---found
# Goliad---found
# Blanco---found
# Lavaca---found
# Hopkins---found
# Wise---found
# Palo Pinto---found
# San Jacinto---found
# Young---found
# Trinity---found
# Swisher---found
# Morris---found
# Oldham---found
# Zapata---found
# Eastland---found
# Comanche---found
# Llano---found
# Live Oak---found
# Leon---found
# Lampasas---found
# Jasper---found
# Camp---found
# Anderson---found
# Robertson---found
# Gonzales---found
# Crane---found
# Hutchinson---found
# Jim Wells---found
# Jones---found
# Karnes---found
# Kerr---found
# McCulloch---found
# Lee---found
# Martin---found
# Aransas---found
# Kleberg---found
# Floyd---found
# Crosby---found
# Dickens---found
# Delta---found
# Dallam---found
# Cooke---found
# Bandera---found
# Concho---found
# Clay---found
# Bee---found
# Winkler---found
# Callahan---found
# Falls---found
# Montague---found
# Tyler---found
# Franklin---found
# Mason---found
# Newton---found
# Pecos---found
# Lamb---found
# Knox---found
# Rains---found
# Jack---found
# Howard---found
# Stephens---found
# Hemphill---found
# Mitchell---found
# Hamilton---found
# Gillespie---found
# Gaines---found
# Frio---found
# Hansford---found

# %%
All_Tex_Counties_df = All_Tex_Counties_df.set_index('CNTY_NM')

# %%
Geo_df = All_Tex_Counties_df.loc[Counties_with_Cases]
Geo_df.head()
# Out:
#            X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# CNTY_NM
# Harris  -95.397821  29.859671       102  48201    7.731110    0.422798
# Dallas  -96.777819  32.766537        57  48113    1.907782    0.226421
# Travis  -97.781947  30.334233       227  48453    2.458272    0.248996
# Tarrant -97.291165  32.771852       220  48439    1.905740    0.225294
# Bexar   -98.519663  29.448845        15  48029    2.729791    0.302846
#
#                  County Location
# CNTY_NM
# Harris   (-95.397821, 29.859671)
# Dallas   (-96.777819, 32.766537)
# Travis   (-97.781947, 30.334233)
# Tarrant  (-97.291165, 32.771852)
# Bexar    (-98.519663, 29.448845)

# %%
Geo_df = Geo_df.reset_index()
Geo_df = Geo_df.rename(columns={"CNTY_NM": "County"})
Geo_df
# Out:
#         County     X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  \
# 0       Harris  -95.397821  29.859671       102  48201    7.731110
# 1       Dallas  -96.777819  32.766537        57  48113    1.907782
# 2       Travis  -97.781947  30.334233       227  48453    2.458272
# 3      Tarrant  -97.291165  32.771852       220  48439    1.905740
# 4        Bexar  -98.519663  29.448845        15  48029    2.729791
# ..         ...         ...        ...       ...    ...         ...
# 171   Hamilton  -98.110667  31.704792        98  48193    1.980431
# 172  Gillespie  -98.946272  30.318002        87  48171    2.150997
# 173     Gaines -102.635125  32.740745        84  48165    2.590419
# 174       Frio  -99.108260  28.867268        83  48163    2.113711
# 175   Hansford -101.354562  36.277532        99  48195    1.965539
#
#      Shape_Area           County Location
# 0      0.422798   (-95.397821, 29.859671)
# 1      0.226421   (-96.777819, 32.766537)
# 2      0.248996   (-97.781947, 30.334233)
# 3      0.225294   (-97.291165, 32.771852)
# 4      0.302846   (-98.519663, 29.448845)
# ..          ...                       ...
# 171    0.206040   (-98.110667, 31.704792)
# 172    0.257844   (-98.946272, 30.318002)
# 173    0.374515  (-102.635125, 32.740745)
# 174    0.271134    (-99.10826, 28.867268)
# 175    0.239189  (-101.354562, 36.277532)
#
# [176 rows x 8 columns]

# %%
result = pd.merge(df, Geo_df, on='County')
result = result.rename(columns={'X (Lat)':'long', 'Y (Long)':'lat'})

result.head()
# Out:
#      No.   County  Cases  Fatalities       long        lat  CNTY_NBR   FIPS  \
# 0   73.0   Harris   3047          34 -95.397821  29.859671       102  48201
# 1   39.0   Dallas   1432          22 -96.777819  32.766537        57  48113
# 2  155.0   Travis    642           7 -97.781947  30.334233       227  48453
# 3  150.0  Tarrant    637          20 -97.291165  32.771852       220  48439
# 4   11.0    Bexar    615          22 -98.519663  29.448845        15  48029
#
#    Shape_Leng  Shape_Area          County Location
# 0    7.731110    0.422798  (-95.397821, 29.859671)
# 1    1.907782    0.226421  (-96.777819, 32.766537)
# 2    2.458272    0.248996  (-97.781947, 30.334233)
# 3    1.905740    0.225294  (-97.291165, 32.771852)
# 4    2.729791    0.302846  (-98.519663, 29.448845)

# %%
result = result[['County', 'Cases', 'Fatalities', 'lat', 'long']]
result
# Out:
#         County  Cases  Fatalities        lat        long
# 0       Harris   3047          34  29.859671  -95.397821
# 1       Dallas   1432          22  32.766537  -96.777819
# 2       Travis    642           7  30.334233  -97.781947
# 3      Tarrant    637          20  32.771852  -97.291165
# 4        Bexar    615          22  29.448845  -98.519663
# ..         ...    ...         ...        ...         ...
# 170   Hamilton      1           0  31.704792  -98.110667
# 171  Gillespie      1           0  30.318002  -98.946272
# 172     Gaines      1           0  32.740745 -102.635125
# 173       Frio      1           0  28.867268  -99.108260
# 174   Hansford      1           0  36.277532 -101.354562
#
# [175 rows x 5 columns]

# %%
def df_to_geojson(df, properties, lat='lat', lon='long'):
    prefix = 'var' + ' data' + ' = '
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point','coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lat],row[lon]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols = ['County', 'Cases', 'Fatalities']
javascript_file = df_to_geojson(result, cols)
# {'type': 'FeatureCollection', 'features': [{'geometry': {'type': 'Point', 'coordinates': [-70.5867, -29.9953, 760]}, 'type': 'Feature', 'properties': {'name': 'A', 'description': 'Place a'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.4933, -30.1217, 1250]}, 'type': 'Feature', 'properties': {'name': 'B', 'description': 'Place b'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.5008, -30.0953, 1185]}, 'type': 'Feature', 'properties': {'name': 'C', 'description': 'Place c'}}]}

# %%
javascript_file
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'County': 'Harris', 'Cases': 3047, 'Fatalities': 34},
#    'geometry': {'type': 'Point', 'coordinates': [29.85967144, -95.39782106]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Dallas', 'Cases': 1432, 'Fatalities': 22},
#    'geometry': {'type': 'Point', 'coordinates': [32.76653746, -96.77781862]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Travis', 'Cases': 642, 'Fatalities': 7},
#    'geometry': {'type': 'Point', 'coordinates': [30.33423319, -97.78194654]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Tarrant', 'Cases': 637, 'Fatalities': 20},
#    'geometry': {'type': 'Point', 'coordinates': [32.77185236, -97.29116473]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Bexar', 'Cases': 615, 'Fatalities': 22},
#    'geometry': {'type': 'Point', 'coordinates': [29.44884523, -98.51966309]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Fort Bend', 'Cases': 485, 'Fatalities': 10},
#    'geometry': {'type': 'Point', 'coordinates': [29.52763253, -95.77090562]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Denton', 'Cases': 426, 'Fatalities': 9},
#    'geometry': {'type': 'Point', 'coordinates': [33.205574, -97.11681154]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Collin', 'Cases': 406, 'Fatalities': 6},
#    'geometry': {'type': 'Point', 'coordinates':
}},
#   {'type': 'Feature',
#    'properties': {'County': 'Karnes', 'Cases': 2, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.90493782, -97.85960621]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Kerr', 'Cases': 2, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.06153035, -99.35016969]}},
#   {'type': 'Feature',
#    'properties': {'County': 'McCulloch', 'Cases': 2, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.19896752, -99.34754972]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Lee', 'Cases': 2, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.31065065, -96.96568735]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Martin', 'Cases': 2, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.30605847, -101.9512464]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Aransas', 'Cases': 2, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.12709562, -96.99258951]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Kleberg', 'Cases': 2, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [27.43274395, -97.72889778]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Floyd', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [34.07239775, -101.3033037]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Crosby', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point',
#     'coordinates': [33.61459873, -101.29986120000001]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Dickens', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.61663428, -100.7788138]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Delta', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.38623601, -95.67221685]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Dallam', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [36.27777107, -102.6021647]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Cooke', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.638465, -97.21247642]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Bandera', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [29.74724753, -99.24637282]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Concho', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.32645211, -99.86413426]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Clay', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.78379717, -98.208958]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Bee', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.41736675, -97.74116811]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Winkler', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.85008609, -103.0484794]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Callahan', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.2977738, -99.37359692]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Falls', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.25317017, -96.93579511]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Montague', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.67496328, -97.72466993]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Tyler', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.7712607, -94.37651432]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Franklin', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.17550691, -95.21841437]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Mason', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.71742293, -99.2263026]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Newton', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.78619977, -93.74462993]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Pecos', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.78100044, -102.7235743]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Lamb', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [34.06861242, -102.3517095]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Knox', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.60614755, -99.74144313]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Rains', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.87004212, -95.79347545]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Jack', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.23345819, -98.1725509]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Howard', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point',
#     'coordinates': [32.30610232, -101.43550970000001]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Stephens', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.73584155, -98.83612016]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Hemphill', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [35.83750155, -100.2704628]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Mitchell', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.30636024, -100.9211128]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Hamilton', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.70479181, -98.11066654]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Gillespie', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.31800246, -98.94627245]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Gaines', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.74074537, -102.6351246]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Frio', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.86726774, -99.10826004]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Hansford', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [36.27753179, -101.3545624]}}]}

# %%
with open('static/js/map.json','w') as f:
    json.dump(javascript_file, f, indent=4, sort_keys=False)

# %%
browser.visit(url4)

# %%
headlines_harris = browser.html
headline_soup = bs(headlines_harris, 'html.parser')

# %%
# lis = headline_soup.find_all('li', class_="headline-list-with-abstract__item")
links = headline_soup.find_all('div', class_="headline-list-with-abstract__headline")

titles = []
hrefs = []

# %%
recent = headline_soup.find_all('div', class_="story-snapshot-with-abstract__headline")[0]

# %%
recent
# Out:
# <div class="story-snapshot-with-abstract__headline">
# <a class="story-snapshot-with-abstract__link" data-tracking="story-snapshot-with-abstract/headlineLinkClicked" href="/article/news/kentucky-mass-gathering-quarantine-in-person-church-service/285-378a3d5e-849b-4b0a-8fb7-aee72ceeb60a">
# <div class="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180" style="overflow-wrap: break-word;">
#                         Kentucky police will record license plate numbers of people who attend church on Easter
#                     </div>
# <div class="story-snapshot-with-abstract__mobile-title dot-ellipsis dot-height-135" style="overflow-wrap: break-word;">
#                         Kentucky police will record license plate numbers of people who attend church on Easter
#                     </div>
# </a>
# </div>

# %%
recent_title = recent.find('div', class_="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180").text.strip()
recent_title
# Out:
# 'Kentucky police will record license plate numbers of people who attend church on Easter'

# %%
titles.append(recent_title)
hrefs.append('https://www.khou.com' + recent.a['href'])

# %%
links
# Out:
# [<div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/trump-announces-opening-our-country-task-force/285-f693f449-eb7b-4f7f-b032-9c2bc3fe2b62">
#                      White House shares hopeful signs, Trump announces 'Opening our Country' task force
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/investigations/coronavirus-houston-improved-air-quality/285-2bf8c487-c621-4772-9b1f-1d129f5019b6">
#                      A side effect of COVID-19 crisis: Houston's air is cleaner
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/katy-priest-brings-good-friday-services-to-community-during-coronavirus-pandemic/285-a9f52e3f-c45d-4ade-88cb-69e04a16eab7">
#                      Katy priest brings Good Friday services to community during coronavirus pandemic
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/houston-food-bank-on-track-to-help-more-people-than-after-harvey/285-c600dcad-bc2e-4c8a-9c62-2e304b213eca">
#                      Houston Food Bank on track to help more people than after Harvey
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/need-a-little-love-your-neighbors-got-you-covered/285-6799655a-3074-412f-b76b-8f4af4e5bac4">
#                      Houston show choir leads message of togetherness during coronavirus pandemic
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/free-counseling-therapy-helpline-for-those-coping-with-covid-19-stress/285-656474c0-43b5-4398-9045-c4603759fdc5">
#                      Feeling overwhelmed? Free counseling helpline for those coping with COVID-19 stress
#                  </a>
#  </div>]

# %%
for article in links:
    
    try:
        
        title = article.find('a', class_="headline-list-with-abstract__link").text
        
        link = article.a['href']
        
        if (title and link):
            
            
            print('-------------')
            print(title)
            print(link)
            titles.append(title.strip())
            hrefs.append('https://www.khou.com' + link)
            
    except:
        print('no')
# Out:
# -------------
#
#                     White House shares hopeful signs, Trump announces 'Opening our Country' task force
#
# /article/news/health/coronavirus/trump-announces-opening-our-country-task-force/285-f693f449-eb7b-4f7f-b032-9c2bc3fe2b62
# -------------
#
#                     A side effect of COVID-19 crisis: Houston's air is cleaner
#
# /article/news/investigations/coronavirus-houston-improved-air-quality/285-2bf8c487-c621-4772-9b1f-1d129f5019b6
# -------------
#
#                     Katy priest brings Good Friday services to community during coronavirus pandemic
#
# /article/news/health/coronavirus/katy-priest-brings-good-friday-services-to-community-during-coronavirus-pandemic/285-a9f52e3f-c45d-4ade-88cb-69e04a16eab7
# -------------
#
#                     Houston Food Bank on track to help more people than after Harvey
#
# /article/news/health/coronavirus/houston-food-bank-on-track-to-help-more-people-than-after-harvey/285-c600dcad-bc2e-4c8a-9c62-2e304b213eca
# -------------
#
#                     Houston show choir leads message of togetherness during coronavirus pandemic
#
# /article/news/health/coronavirus/need-a-little-love-your-neighbors-got-you-covered/285-6799655a-3074-412f-b76b-8f4af4e5bac4
# -------------
#
#                     Feeling overwhelmed? Free counseling helpline for those coping with COVID-19 stress
#
# /article/news/health/coronavirus/free-counseling-therapy-helpline-for-those-coping-with-covid-19-stress/285-656474c0-43b5-4398-9045-c4603759fdc5

# %%
latest_headlines_df = pd.DataFrame(list(zip(titles, hrefs)), columns =['Headline', 'link'])

# %%
latest_headlines_df
# Out:
#                                             Headline  \
# 0  Kentucky police will record license plate numb...
# 1  White House shares hopeful signs, Trump announ...
# 2  A side effect of COVID-19 crisis: Houston's ai...
# 3  Katy priest brings Good Friday services to com...
# 4  Houston Food Bank on track to help more people...
# 5  Houston show choir leads message of togetherne...
# 6  Feeling overwhelmed? Free counseling helpline ...
#
#                                                 link
# 0  https://www.khou.com/article/news/kentucky-mas...
# 1  https://www.khou.com/article/news/health/coron...
# 2  https://www.khou.com/article/news/investigatio...
# 3  https://www.khou.com/article/news/health/coron...
# 4  https://www.khou.com/article/news/health/coron...
# 5  https://www.khou.com/article/news/health/coron...
# 6  https://www.khou.com/article/news/health/coron...

# %%
latest_headlines_df.to_csv('static/csv/headlines.csv', index=False, header=True)

# %%
browser.quit()
