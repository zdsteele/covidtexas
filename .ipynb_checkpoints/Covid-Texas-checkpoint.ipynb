# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from time import sleep
from datetime import datetime
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import time
import json
import os
import shutil

# %%
# Path to chromedriver.exe
executable_path = {'executable_path':'C:/Users/zacha/AppData/Local/bin/chromedriver.exe'}

# Open the Splinter Browswer
browser = Browser('chrome', **executable_path)

# %%
# URL to find information on Coronavirus
url1 = "https://txdshs.maps.arcgis.com/apps/opsdashboard/index.html#/ed483ecd702b4298ab01e8b9cafc8b83"

url2 = "https://dshs.texas.gov/coronavirus/"

url3 = "http://publichealth.harriscountytx.gov/Resources/2019-Novel-Coronavirus/Harris-County-COVID-19-Confirmed-Cases"

url4 = "https://www.khou.com/section/news/health/coronavirus"

# %%
# Visiting the url 
browser.visit(url1)

# %%
time.sleep(7)# Creating the Beautiful soup for URL
html = browser.html
soup = bs(html, 'html.parser')

# %%
# All the Texas counties
# counties = soup.find('nav', attrs={'class':'feature-list'})

# getting all the spans with the information for each Texas county
# rows = counties.find_all('span')

# %%
# counter = 0

# county = []
# cases = []

# for row in rows:
#     try:
#         print(rows[counter].text.strip().split('\n'))
#         county.append(rows[counter].text.strip().split('\n')[0])
#         cases.append(rows[counter].text.strip().split('\n')[1])
#         counter = counter + 3
        
#     except:
#         print('failure')

# %%
# df = pd.DataFrame(list(zip(county, cases)), columns =['Texas_County', 'COVID_19_Cases'])
# df

# %%
# Droping the word 'County'
# df['Texas_County'] = df['Texas_County'].apply(lambda x : x.split(' County')[0])

# %%
# Revise? 
reported_cases = soup.find_all('text')[6].text
reported_cases
# Out:
# '2,877'

# %%
deaths = soup.find_all('text')[8].text
deaths
# Out:
# '38'

# %%
df_stats = pd.DataFrame({'Cases':[reported_cases], 'Deaths':[deaths]})
df_stats.to_csv('static/csv/stats.csv', index=False)

# %%
# Getting Total Cases and Deaths 
browser.visit(url2)

# %%
browser.find_by_text('Accessible version (Excel)').click()
time.sleep(5)

# %%
source = 'C:/Users/zacha/Downloads/'
destination = 'C:/Users/zacha/Documents/COVID-19/'
filename = 'CaseCountData.xlsx'

# %%
shutil.move(os.path.join(source, filename), os.path.join(destination, filename))
# Out:
# 'C:/Users/zacha/Documents/COVID-19/CaseCountData.xlsx'

# %%
# dest = shutil.move(source, destination, )

# %%
df = pd.read_excel('CaseCountData.xlsx', header=1).dropna()
df.sort_values(by=['Positive'], ascending=False, inplace=True)
df['County'] = df.apply(lambda x: x['County'].rstrip(), axis=1)
df
# Out:
#        No.    County  Positive  Fatalities
# 48    49.0    Harris       526           4
# 25    26.0    Dallas       488          10
# 107  108.0    Travis       200           1
# 28    29.0    Denton       165           2
# 6      7.0     Bexar       157           5
# ..     ...       ...       ...         ...
# 39    40.0  Franklin         1           0
# 36    37.0    Fannin         1           0
# 91    92.0      Polk         1           0
# 34    35.0     Erath         1           0
# 123  124.0     Young         1           0
#
# [124 rows x 4 columns]

# %%
browser.visit(url3)

# %%
harris_table = browser.find_by_id('covidtable')

# %%
html_harris = browser.html
harris_soup = bs(html_harris, 'html.parser')

# %%
harris_data = []
table = harris_soup.find('table', attrs={'id':'covidtable'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    harris_data.append([ele for ele in cols if ele]) # Get rid of empty values

# %%
columns = ['Patient', 'Sex', 'Age_Range', 'Location','Exposure', 'Status']

# %%
harris_data = harris_data[1:]

# %%
harris_df = pd.DataFrame(harris_data, columns=columns)

# %%
harris_df.sort_values(by=['Age_Range'], inplace=True)

# %%
harris_df
# Out:
#     Patient     Sex Age_Range Location                   Exposure    Status
# 43       44    Male     0 - 9       NW  Possible Exposure to Case    Active
# 45       46  Female     0 - 9       NW  Possible Exposure to Case    Active
# 172     173  Female     0 - 9       NW  Possible Exposure to Case    Active
# 185     186  Female     0 - 9       SE  Possible Exposure to Case    Active
# 147     148    Male   10 - 19       SE  Possible Exposure to Case    Active
# ..      ...     ...       ...      ...                        ...       ...
# 154     155  Female       80+       SE      Investigation Pending    Active
# 246     247  Female       80+       SW      Investigation Pending    Active
# 15       16    Male       80+       NW          No Known Exposure  Deceased
# 158     159  Female       80+       NW          History of Travel    Active
# 193     194  Female       80+       SE          No Known Exposure    Active
#
# [254 rows x 6 columns]

# %%
harris_df.to_csv('static/csv/harris_stats.csv', index=False, header=True)

# %%
harris_df.head()
# Out:
#     Patient     Sex Age_Range Location                   Exposure  Status
# 43       44    Male     0 - 9       NW  Possible Exposure to Case  Active
# 45       46  Female     0 - 9       NW  Possible Exposure to Case  Active
# 172     173  Female     0 - 9       NW  Possible Exposure to Case  Active
# 185     186  Female     0 - 9       SE  Possible Exposure to Case  Active
# 147     148    Male   10 - 19       SE  Possible Exposure to Case  Active

# %%
All_Tex_Counties_df = pd.read_csv('static/csv/Texas_Counties.csv')
All_Tex_Counties_df.head()
# Out:
#      X (Lat)   Y (Long)    CNTY_NM  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# 0 -97.492799  29.456415   Gonzales        90  48177    2.124911    0.257805
# 1 -98.697292  27.043405   Jim Hogg       125  48247    2.271751    0.267624
# 2 -97.681378  26.924094     Kenedy        66  48261    5.067864    0.389397
# 3 -96.965687  30.310651        Lee       144  48287    2.213853    0.153990
# 4 -95.853568  32.211881  Henderson       108  48213    3.152909    0.235056
#
#            County Location
# 0  (-97.492799, 29.456415)
# 1  (-98.697292, 27.043405)
# 2  (-97.681378, 26.924094)
# 3  (-96.965687, 30.310651)
# 4  (-95.853568, 32.211881)

# %%
All_Tex_Counties = All_Tex_Counties_df['CNTY_NM'].tolist()

# %%
df_counties = df['County'].tolist()

# %%
Counties_with_Cases = []

for i in df_counties:
    
    if i.rstrip() in All_Tex_Counties:
        Counties_with_Cases.append(i.rstrip())
        print(f'{i}---found')
        
    elif i == 'DeWitt':
        Counties_with_Cases.append('De Witt')
        print(f'{i}---found')
    else:
        print(f'Houston we have a problem: {i}')
# Out:
# Harris---found
# Dallas---found
# Travis---found
# Denton---found
# Bexar---found
# Tarrant---found
# Collin---found
# Fort Bend---found
# Galveston---found
# Montgomery---found
# Brazoria---found
# Lubbock---found
# Brazos---found
# El Paso---found
# Williamson---found
# McLennan---found
# Smith---found
# Webb---found
# Bell---found
# Hidalgo---found
# Wichita---found
# Nueces---found
# Cameron---found
# Jefferson---found
# Hays---found
# Ellis---found
# Guadalupe---found
# Matagorda---found
# Midland---found
# Comal---found
# Hardin---found
# Castro---found
# Johnson---found
# Washington---found
# Kendall---found
# Taylor---found
# Hockley---found
# Bastrop---found
# Randall---found
# Wharton---found
# Victoria---found
# Grayson---found
# Chambers---found
# Val Verde---found
# Potter---found
# Gregg---found
# Orange---found
# Tom Green---found
# Parker---found
# Bowie---found
# Rockwall---found
# Llano---found
# Lamar---found
# Angelina---found
# Medina---found
# Navarro---found
# Terry---found
# Walker---found
# Waller---found
# Rusk---found
# Kaufman---found
# DeWitt---found
# Ector---found
# Hood---found
# Brown---found
# Hunt---found
# Calhoun---found
# Eastland---found
# Robertson---found
# Aransas---found
# Fayette---found
# Starr---found
# Upshur---found
# Nacogdoches---found
# Deaf Smith---found
# Shelby---found
# Uvalde---found
# Cass---found
# Grimes---found
# Oldham---found
# Karnes---found
# Milam---found
# Limestone---found
# Wilson---found
# Atascosa---found
# Willacy---found
# Austin---found
# Liberty---found
# Van Zandt---found
# Hopkins---found
# Lynn---found
# Burnet---found
# Cherokee---found
# Coryell---found
# Caldwell---found
# Blanco---found
# Dawson---found
# Burleson---found
# Swisher---found
# Wise---found
# Crane---found
# Falls---found
# San Patricio---found
# San Jacinto---found
# Jim Wells---found
# Kleberg---found
# Jackson---found
# Lamb---found
# Lavaca---found
# Leon---found
# Martin---found
# Maverick---found
# Hill---found
# Harrison---found
# Hale---found
# Montague---found
# Moore---found
# Morris---found
# Gaines---found
# Franklin---found
# Fannin---found
# Polk---found
# Erath---found
# Young---found

# %%
All_Tex_Counties_df = All_Tex_Counties_df.set_index('CNTY_NM')

# %%
Geo_df = All_Tex_Counties_df.loc[Counties_with_Cases]
Geo_df.head()
# Out:
#            X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# CNTY_NM
# Harris  -95.397821  29.859671       102  48201    7.731110    0.422798
# Dallas  -96.777819  32.766537        57  48113    1.907782    0.226421
# Travis  -97.781947  30.334233       227  48453    2.458272    0.248996
# Denton  -97.116812  33.205574        61  48121    1.969324    0.238359
# Bexar   -98.519663  29.448845        15  48029    2.729791    0.302846
#
#                  County Location
# CNTY_NM
# Harris   (-95.397821, 29.859671)
# Dallas   (-96.777819, 32.766537)
# Travis   (-97.781947, 30.334233)
# Denton   (-97.116812, 33.205574)
# Bexar    (-98.519663, 29.448845)

# %%
Geo_df = Geo_df.reset_index()
Geo_df = Geo_df.rename(columns={"CNTY_NM": "County"})
Geo_df
# Out:
#        County    X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# 0      Harris -95.397821  29.859671       102  48201    7.731110    0.422798
# 1      Dallas -96.777819  32.766537        57  48113    1.907782    0.226421
# 2      Travis -97.781947  30.334233       227  48453    2.458272    0.248996
# 3      Denton -97.116812  33.205574        61  48121    1.969324    0.238359
# 4       Bexar -98.519663  29.448845        15  48029    2.729791    0.302846
# ..        ...        ...        ...       ...    ...         ...         ...
# 119  Franklin -95.218414  33.175507        81  48159    1.422054    0.073839
# 120    Fannin -96.106568  33.593969        75  48147    2.266623    0.226257
# 121      Polk -94.829949  30.792510       187  48373    2.781485    0.271059
# 122     Erath -98.217228  32.236404        73  48143    2.114378    0.269412
# 123     Young -98.687814  33.176708       252  48503    1.941651    0.233022
#
#              County Location
# 0    (-95.397821, 29.859671)
# 1    (-96.777819, 32.766537)
# 2    (-97.781947, 30.334233)
# 3    (-97.116812, 33.205574)
# 4    (-98.519663, 29.448845)
# ..                       ...
# 119  (-95.218414, 33.175507)
# 120  (-96.106568, 33.593969)
# 121   (-94.829949, 30.79251)
# 122  (-98.217228, 32.236404)
# 123  (-98.687814, 33.176708)
#
# [124 rows x 8 columns]

# %%
result = pd.merge(df, Geo_df, on='County')
result = result.rename(columns={'X (Lat)':'long', 'Y (Long)':'lat'})

result.head()
# Out:
#      No.  County  Positive  Fatalities       long        lat  CNTY_NBR   FIPS  \
# 0   49.0  Harris       526           4 -95.397821  29.859671       102  48201
# 1   26.0  Dallas       488          10 -96.777819  32.766537        57  48113
# 2  108.0  Travis       200           1 -97.781947  30.334233       227  48453
# 3   29.0  Denton       165           2 -97.116812  33.205574        61  48121
# 4    7.0   Bexar       157           5 -98.519663  29.448845        15  48029
#
#    Shape_Leng  Shape_Area          County Location
# 0    7.731110    0.422798  (-95.397821, 29.859671)
# 1    1.907782    0.226421  (-96.777819, 32.766537)
# 2    2.458272    0.248996  (-97.781947, 30.334233)
# 3    1.969324    0.238359  (-97.116812, 33.205574)
# 4    2.729791    0.302846  (-98.519663, 29.448845)

# %%
result = result[['County', 'Positive', 'Fatalities', 'lat', 'long']]
result
# Out:
#        County  Positive  Fatalities        lat       long
# 0      Harris       526           4  29.859671 -95.397821
# 1      Dallas       488          10  32.766537 -96.777819
# 2      Travis       200           1  30.334233 -97.781947
# 3      Denton       165           2  33.205574 -97.116812
# 4       Bexar       157           5  29.448845 -98.519663
# ..        ...       ...         ...        ...        ...
# 118  Franklin         1           0  33.175507 -95.218414
# 119    Fannin         1           0  33.593969 -96.106568
# 120      Polk         1           0  30.792510 -94.829949
# 121     Erath         1           0  32.236404 -98.217228
# 122     Young         1           0  33.176708 -98.687814
#
# [123 rows x 5 columns]

# %%
def df_to_geojson(df, properties, lat='lat', lon='long'):
    prefix = 'var' + ' data' + ' = '
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point','coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lat],row[lon]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols = ['County', 'Positive', 'Fatalities']
javascript_file = df_to_geojson(result, cols)
# {'type': 'FeatureCollection', 'features': [{'geometry': {'type': 'Point', 'coordinates': [-70.5867, -29.9953, 760]}, 'type': 'Feature', 'properties': {'name': 'A', 'description': 'Place a'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.4933, -30.1217, 1250]}, 'type': 'Feature', 'properties': {'name': 'B', 'description': 'Place b'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.5008, -30.0953, 1185]}, 'type': 'Feature', 'properties': {'name': 'C', 'description': 'Place c'}}]}

# %%
with open('static/js/map.json','w') as f:
    json.dump(javascript_file, f, indent=4, sort_keys=False)

# %%
browser.visit(url4)

# %%
headlines_harris = browser.html
headline_soup = bs(headlines_harris, 'html.parser')

# %%
# lis = headline_soup.find_all('li', class_="headline-list-with-abstract__item")
links = headline_soup.find_all('div', class_="headline-list-with-abstract__headline")

titles = []
hrefs = []

# %%
recent = headline_soup.find_all('div', class_="story-snapshot-with-abstract__headline")[0]

# %%
recent
# Out:
# <div class="story-snapshot-with-abstract__headline">
# <a class="story-snapshot-with-abstract__link" data-tracking="story-snapshot-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/star-trek-next-generation-zoom-birthday-party/285-726afcbe-a309-47cf-a358-a87e4bceb3b9">
# <div class="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180" style="overflow-wrap: break-word;">
#                         'Star Trek' cast had a Zoom birthday party for Counselor Troi because of coronavirus
#                     </div>
# <div class="story-snapshot-with-abstract__mobile-title dot-ellipsis dot-height-135" style="overflow-wrap: break-word;">
#                         'Star Trek' cast had a Zoom birthday party for Counselor Troi because of coronavirus
#                     </div>
# </a>
# </div>

# %%
recent_title = recent.find('div', class_="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180").text.strip()
recent_title
# Out:
# "'Star Trek' cast had a Zoom birthday party for Counselor Troi because of coronavirus"

# %%
titles.append(recent_title)
hrefs.append('https://www.khou.com' + recent.a['href'])

# %%
links
# Out:
# [<div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-live-blog-updates-march-31-2020/285-7f2288af-9471-43a7-afd5-c8a3e9a094b3">
#                      Coronavirus live updates: Japan extends travel warnings; Wimbledon canceled?
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/ncaa-to-give-spring-sport-athletes-extra-year-of-eligibility/285-9054fde5-d8a1-473d-9bbc-b0201ce1d9d1">
#                      NCAA to give spring sport athletes extra year of eligibility
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/houston-coronavirus-testing/285-c95ce8c4-f876-4d6c-8645-4922578617df">
#                      Here's how Houston-area residents can get tested for coronavirus
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/houston-area-coronavirus-cases/285-192b8879-08b6-4ec0-8a0f-a0487ead1453">
#                      Map: Keeping track of Houston-area coronavirus cases
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-updates-houston-live-log-march-30/285-b2f89f1b-939c-4a9e-8a03-f5b42d8ef51c">
#                      Coronavirus updates: Harris County 'stay home, work safe' will be extended, Judge Lina Hildago says
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/texas-governor-orders-travel-restrictions-for-anyone-coming-into-state-from-louisiana/285-24a93360-4615-41e9-8099-bc7cb9727ac7">
#                      Here's what anyone living or working in Louisiana needs to know before traveling back to Texas
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/video/news/health/coronavirus/quarantine-order-is-in-effect-for-louisiana-drivers-coming-into-texas/285-2ff7e4ae-14d5-4da9-9867-cfbd6b2758c9">
#                      Not much has changed at Texas-Louisiana border now that quarantine order is in effect
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/video/news/health/coronavirus/watch-out-for-this-stimulus-check-scam/285-ed984f64-1fd6-43dd-b785-1d5e0f4f0cbd">
#                      Watch out for this stimulus check scam
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/video/news/local/video/10-pm-coronavirus-headlines-for-monday-march-30/285-c4a29440-0b75-4e6b-8d06-dacc3b30df70">
#                      10 p.m. coronavirus headlines for Monday, March 30
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/immediate-shelter-in-place-order-issued-at-apartment-complex-in-the-woodlands-after-12-residents-test-positive-for-covid-19/285-8c1bd9f2-a59e-4b2c-a4c7-91db001a520b">
#                      Immediate shelter-in-place order issued at apartment complex in The Woodlands after 12 residents test positive for COVID-19
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/results-of-covid-19-tests-take-nearly-two-weeks-to-come-back/285-dd0b67a5-4a43-4235-87f6-5c95bb2d5467">
#                      Some COVID-19 test results taking nearly two weeks to come back
#                  </a>
#  </div>]

# %%
for article in links:
    
    try:
        
        title = article.find('a', class_="headline-list-with-abstract__link").text
        
        link = article.a['href']
        
        if (title and link):
            
            
            print('-------------')
            print(title)
            print(link)
            titles.append(title.strip())
            hrefs.append('https://www.khou.com' + link)
            
    except:
        print('no')
# Out:
# -------------
#
#                     Coronavirus live updates: Japan extends travel warnings; Wimbledon canceled?
#
# /article/news/health/coronavirus/coronavirus-live-blog-updates-march-31-2020/285-7f2288af-9471-43a7-afd5-c8a3e9a094b3
# -------------
#
#                     NCAA to give spring sport athletes extra year of eligibility
#
# /article/news/health/coronavirus/ncaa-to-give-spring-sport-athletes-extra-year-of-eligibility/285-9054fde5-d8a1-473d-9bbc-b0201ce1d9d1
# -------------
#
#                     Here's how Houston-area residents can get tested for coronavirus
#
# /article/news/health/coronavirus/houston-coronavirus-testing/285-c95ce8c4-f876-4d6c-8645-4922578617df
# -------------
#
#                     Map: Keeping track of Houston-area coronavirus cases
#
# /article/news/health/coronavirus/houston-area-coronavirus-cases/285-192b8879-08b6-4ec0-8a0f-a0487ead1453
# -------------
#
#                     Coronavirus updates: Harris County 'stay home, work safe' will be extended, Judge Lina Hildago says
#
# /article/news/health/coronavirus/coronavirus-updates-houston-live-log-march-30/285-b2f89f1b-939c-4a9e-8a03-f5b42d8ef51c
# -------------
#
#                     Here's what anyone living or working in Louisiana needs to know before traveling back to Texas
#
# /article/news/health/coronavirus/texas-governor-orders-travel-restrictions-for-anyone-coming-into-state-from-louisiana/285-24a93360-4615-41e9-8099-bc7cb9727ac7
# -------------
#
#                     Not much has changed at Texas-Louisiana border now that quarantine order is in effect
#
# /video/news/health/coronavirus/quarantine-order-is-in-effect-for-louisiana-drivers-coming-into-texas/285-2ff7e4ae-14d5-4da9-9867-cfbd6b2758c9
# -------------
#
#                     Watch out for this stimulus check scam
#
# /video/news/health/coronavirus/watch-out-for-this-stimulus-check-scam/285-ed984f64-1fd6-43dd-b785-1d5e0f4f0cbd
# -------------
#
#                     10 p.m. coronavirus headlines for Monday, March 30
#
# /video/news/local/video/10-pm-coronavirus-headlines-for-monday-march-30/285-c4a29440-0b75-4e6b-8d06-dacc3b30df70
# -------------
#
#                     Immediate shelter-in-place order issued at apartment complex in The Woodlands after 12 residents test positive for COVID-19
#
# /article/news/health/coronavirus/immediate-shelter-in-place-order-issued-at-apartment-complex-in-the-woodlands-after-12-residents-test-positive-for-covid-19/285-8c1bd9f2-a59e-4b2c-a4c7-91db001a520b
# -------------
#
#                     Some COVID-19 test results taking nearly two weeks to come back
#
# /article/news/health/coronavirus/results-of-covid-19-tests-take-nearly-two-weeks-to-come-back/285-dd0b67a5-4a43-4235-87f6-5c95bb2d5467

# %%
latest_headlines_df = pd.DataFrame(list(zip(titles, hrefs)), columns =['Headline', 'link'])

# %%
latest_headlines_df
# Out:
#                                              Headline  \
# 0   'Star Trek' cast had a Zoom birthday party for...
# 1   Coronavirus live updates: Japan extends travel...
# 2   NCAA to give spring sport athletes extra year ...
# 3   Here's how Houston-area residents can get test...
# 4   Map: Keeping track of Houston-area coronavirus...
# 5   Coronavirus updates: Harris County 'stay home,...
# 6   Here's what anyone living or working in Louisi...
# 7   Not much has changed at Texas-Louisiana border...
# 8              Watch out for this stimulus check scam
# 9   10 p.m. coronavirus headlines for Monday, Marc...
# 10  Immediate shelter-in-place order issued at apa...
# 11  Some COVID-19 test results taking nearly two w...
#
#                                                  link
# 0   https://www.khou.com/article/news/health/coron...
# 1   https://www.khou.com/article/news/health/coron...
# 2   https://www.khou.com/article/news/health/coron...
# 3   https://www.khou.com/article/news/health/coron...
# 4   https://www.khou.com/article/news/health/coron...
# 5   https://www.khou.com/article/news/health/coron...
# 6   https://www.khou.com/article/news/health/coron...
# 7   https://www.khou.com/video/news/health/coronav...
# 8   https://www.khou.com/video/news/health/coronav...
# 9   https://www.khou.com/video/news/local/video/10...
# 10  https://www.khou.com/article/news/health/coron...
# 11  https://www.khou.com/article/news/health/coron...

# %%
latest_headlines_df.to_csv('static/csv/headlines.csv', index=False, header=True)

# %%
browser.quit()
