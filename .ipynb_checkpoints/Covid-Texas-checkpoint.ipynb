# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from time import sleep
from datetime import datetime
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import time
import json
import os
import shutil

# %%
# Path to chromedriver.exe
executable_path = {'executable_path':'C:/Users/zacha/AppData/Local/bin/chromedriver.exe'}

# Open the Splinter Browswer
browser = Browser('chrome', **executable_path)

# %%
# URL to find information on Coronavirus
url1 = "https://txdshs.maps.arcgis.com/apps/opsdashboard/index.html#/ed483ecd702b4298ab01e8b9cafc8b83"

url2 = "https://dshs.texas.gov/coronavirus/"

# url3 = "http://publichealth.harriscountytx.gov/Resources/2019-Novel-Coronavirus/Harris-County-COVID-19-Confirmed-Cases"

url4 = "https://www.khou.com/section/news/health/coronavirus"

# %%
# Visiting the url 
browser.visit(url1)

# %%
time.sleep(7)# Creating the Beautiful soup for URL
html = browser.html
soup = bs(html, 'html.parser')

# %%
# Revise? 
reported_cases = soup.find_all('text')[9].text
reported_cases
# Out:
# '17,371'

# %%
deaths = soup.find_all('text')[11].text
deaths
# Out:
# '428'

# %%
df_stats = pd.DataFrame({'Cases':[reported_cases], 'Deaths':[deaths]})
df_stats.to_csv('static/csv/stats.csv', index=False)

# %%
# Getting Total Cases and Deaths 
browser.visit(url2)

# %%
browser.find_by_text('Accessible version').click()
time.sleep(5)

# %%
source = 'C:/Users/zacha/Downloads/'
destination = 'C:/Users/zacha/Documents/COVID-19/'
filename = 'CaseCountData.xlsx'

# %%
shutil.move(os.path.join(source, filename), os.path.join(destination, filename))
# Out:
# 'C:/Users/zacha/Documents/COVID-19/CaseCountData.xlsx'

# %%
# dest = shutil.move(source, destination, )

# %%
df = pd.read_excel('CaseCountData.xlsx', header=1).dropna()
df.sort_values(by=['Positive'], ascending=False, inplace=True)
df['County'] = df.apply(lambda x: x['County'].rstrip(), axis=1)
df.to_csv('static/csv/CaseCountData.csv', index=False, header=True)

df
# Out:
#        No.     County  Positive  Fatalities
# 77    78.0     Harris      4306          63
# 40    41.0     Dallas      2066          50
# 163  164.0    Tarrant      1093          34
# 168  169.0     Travis      1029          18
# 11    12.0      Bexar       918          37
# ..     ...        ...       ...         ...
# 80    81.0   Hemphill         1           0
# 132  133.0     Motley         1           0
# 65    66.0  Gillespie         1           0
# 62    63.0       Frio         1           0
# 191  192.0     Zavala         1           0
#
# [192 rows x 4 columns]

# %%
df = df.rename(columns={"Positive": "Cases"})

# %%
df
# Out:
#        No.     County  Cases  Fatalities
# 77    78.0     Harris   4306          63
# 40    41.0     Dallas   2066          50
# 163  164.0    Tarrant   1093          34
# 168  169.0     Travis   1029          18
# 11    12.0      Bexar    918          37
# ..     ...        ...    ...         ...
# 80    81.0   Hemphill      1           0
# 132  133.0     Motley      1           0
# 65    66.0  Gillespie      1           0
# 62    63.0       Frio      1           0
# 191  192.0     Zavala      1           0
#
# [192 rows x 4 columns]

# %%
# browser.visit(url3)

# %%
# harris_table = browser.find_by_id('covidtable')

# %%
# html_harris = browser.html
# harris_soup = bs(html_harris, 'html.parser')

# %%
# harris_data = []
# table = harris_soup.find('table', attrs={'id':'covidtable'})
# table_body = table.find('tbody')

# rows = table_body.find_all('tr')
# for row in rows:
#     cols = row.find_all('td')
#     cols = [ele.text.strip() for ele in cols]
#     harris_data.append([ele for ele in cols if ele])

# %%
# columns = ['Patient', 'Sex', 'Age_Range', 'Location','Exposure', 'Status']

# %%
# harris_data = harris_data[1:]

# %%
# harris_df = pd.DataFrame(harris_data, columns=columns)

# %%
# harris_df.sort_values(by=['Age_Range'], inplace=True)

# %%
# harris_df.to_csv('static/csv/harris_stats.csv', index=False, header=True)

# %%
# harris_df.head()

# %%
All_Tex_Counties_df = pd.read_csv('static/csv/Texas_Counties.csv')
All_Tex_Counties_df.head()
# Out:
#      X (Lat)   Y (Long)    CNTY_NM  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# 0 -97.492799  29.456415   Gonzales        90  48177    2.124911    0.257805
# 1 -98.697292  27.043405   Jim Hogg       125  48247    2.271751    0.267624
# 2 -97.681378  26.924094     Kenedy        66  48261    5.067864    0.389397
# 3 -96.965687  30.310651        Lee       144  48287    2.213853    0.153990
# 4 -95.853568  32.211881  Henderson       108  48213    3.152909    0.235056
#
#            County Location
# 0  (-97.492799, 29.456415)
# 1  (-98.697292, 27.043405)
# 2  (-97.681378, 26.924094)
# 3  (-96.965687, 30.310651)
# 4  (-95.853568, 32.211881)

# %%
All_Tex_Counties = All_Tex_Counties_df['CNTY_NM'].tolist()

# %%
df_counties = df['County'].tolist()

# %%
Counties_with_Cases = []

for i in df_counties:
    
    if i.rstrip() in All_Tex_Counties:
        Counties_with_Cases.append(i.rstrip())
        print(f'{i}---found')
        
    elif i == 'DeWitt':
        Counties_with_Cases.append('De Witt')
        print(f'{i}---found')
    else:
        print(f'Houston we have a problem: {i}')
# Out:
# Harris---found
# Dallas---found
# Tarrant---found
# Travis---found
# Bexar---found
# Fort Bend---found
# Denton---found
# Collin---found
# El Paso---found
# Galveston---found
# Lubbock---found
# Montgomery---found
# Brazoria---found
# Cameron---found
# Webb---found
# Hidalgo---found
# Brazos---found
# Jefferson---found
# Williamson---found
# Bell---found
# Hays---found
# Smith---found
# Potter---found
# Randall---found
# Taylor---found
# Victoria---found
# Nueces---found
# Ellis---found
# McLennan---found
# Moore---found
# Nacogdoches---found
# Coryell---found
# Walker---found
# Hardin---found
# Wichita---found
# Ector---found
# Bowie---found
# Shelby---found
# Guadalupe---found
# Matagorda---found
# Orange---found
# Gregg---found
# Washington---found
# Comal---found
# Bastrop---found
# Tom Green---found
# Midland---found
# Harrison---found
# Kaufman---found
# Johnson---found
# Panola---found
# Chambers---found
# Rockwall---found
# Wharton---found
# Rusk---found
# Liberty---found
# Hunt---found
# Angelina---found
# Waller---found
# Donley---found
# Calhoun---found
# Parker---found
# Navarro---found
# Grayson---found
# Andrews---found
# Wilson---found
# Gray---found
# Medina---found
# Fayette---found
# Hood---found
# Hockley---found
# San Augustine---found
# Kendall---found
# Polk---found
# Erath---found
# Henderson---found
# Val Verde---found
# Brown---found
# Austin---found
# Maverick---found
# Dawson---found
# Van Zandt---found
# Deaf Smith---found
# Castro---found
# Hale---found
# Limestone---found
# San Jacinto---found
# DeWitt---found
# Hill---found
# Terry---found
# Grimes---found
# Upshur---found
# Atascosa---found
# Milam---found
# Burleson---found
# San Patricio---found
# Cherokee---found
# Wise---found
# Burnet---found
# Titus---found
# Colorado---found
# Caldwell---found
# Willacy---found
# Lamar---found
# Starr---found
# Trinity---found
# Wood---found
# Palo Pinto---found
# Camp---found
# Zapata---found
# Sherman---found
# Anderson---found
# Hutchinson---found
# Uvalde---found
# Jasper---found
# Goliad---found
# Hamilton---found
# Montague---found
# Bee---found
# Fannin---found
# Blanco---found
# Cass---found
# Leon---found
# Pecos---found
# Kleberg---found
# Lynn---found
# Swisher---found
# Jackson---found
# Kerr---found
# Bandera---found
# Morris---found
# Tyler---found
# Young---found
# Lavaca---found
# Hopkins---found
# Winkler---found
# Oldham---found
# Jones---found
# Eastland---found
# McCulloch---found
# Marion---found
# Dallam---found
# Jack---found
# Clay---found
# Llano---found
# Live Oak---found
# Comanche---found
# Karnes---found
# Newton---found
# Cooke---found
# Gaines---found
# Gonzales---found
# Crane---found
# Jim Wells---found
# Lamb---found
# Rains---found
# Robertson---found
# Aransas---found
# Martin---found
# Floyd---found
# Lee---found
# Lampasas---found
# Callahan---found
# Bosque---found
# Crosby---found
# Concho---found
# Delta---found
# Wilbarger---found
# Dickens---found
# Armstrong---found
# Dimmit---found
# Duval---found
# Falls---found
# Hansford---found
# Franklin---found
# Freestone---found
# Mitchell---found
# Mason---found
# Madison---found
# Red River---found
# Roberts---found
# Sabine---found
# Scurry---found
# La Salle---found
# Knox---found
# Stephens---found
# Howard---found
# Hemphill---found
# Motley---found
# Gillespie---found
# Frio---found
# Zavala---found

# %%
All_Tex_Counties_df = All_Tex_Counties_df.set_index('CNTY_NM')

# %%
Geo_df = All_Tex_Counties_df.loc[Counties_with_Cases]
Geo_df.head()
# Out:
#            X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# CNTY_NM
# Harris  -95.397821  29.859671       102  48201    7.731110    0.422798
# Dallas  -96.777819  32.766537        57  48113    1.907782    0.226421
# Tarrant -97.291165  32.771852       220  48439    1.905740    0.225294
# Travis  -97.781947  30.334233       227  48453    2.458272    0.248996
# Bexar   -98.519663  29.448845        15  48029    2.729791    0.302846
#
#                  County Location
# CNTY_NM
# Harris   (-95.397821, 29.859671)
# Dallas   (-96.777819, 32.766537)
# Tarrant  (-97.291165, 32.771852)
# Travis   (-97.781947, 30.334233)
# Bexar    (-98.519663, 29.448845)

# %%
Geo_df = Geo_df.reset_index()
Geo_df = Geo_df.rename(columns={"CNTY_NM": "County"})
Geo_df
# Out:
#         County     X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  \
# 0       Harris  -95.397821  29.859671       102  48201    7.731110
# 1       Dallas  -96.777819  32.766537        57  48113    1.907782
# 2      Tarrant  -97.291165  32.771852       220  48439    1.905740
# 3       Travis  -97.781947  30.334233       227  48453    2.458272
# 4        Bexar  -98.519663  29.448845        15  48029    2.729791
# ..         ...         ...        ...       ...    ...         ...
# 187   Hemphill -100.270463  35.837502       107  48211    1.952454
# 188     Motley -100.779896  34.074090       173  48345    2.003717
# 189  Gillespie  -98.946272  30.318002        87  48171    2.150997
# 190       Frio  -99.108260  28.867268        83  48163    2.113711
# 191     Zavala  -99.761020  28.865306       254  48507    2.300184
#
#      Shape_Area           County Location
# 0      0.422798   (-95.397821, 29.859671)
# 1      0.226421   (-96.777819, 32.766537)
# 2      0.225294   (-97.291165, 32.771852)
# 3      0.248996   (-97.781947, 30.334233)
# 4      0.302846   (-98.519663, 29.448845)
# ..          ...                       ...
# 187    0.235629  (-100.270463, 35.837502)
# 188    0.250394   (-100.779896, 34.07409)
# 189    0.257844   (-98.946272, 30.318002)
# 190    0.271134    (-99.10826, 28.867268)
# 191    0.311031    (-99.76102, 28.865306)
#
# [192 rows x 8 columns]

# %%
result = pd.merge(df, Geo_df, on='County')
result = result.rename(columns={'X (Lat)':'long', 'Y (Long)':'lat'})

result.head()
# Out:
#      No.   County  Cases  Fatalities       long        lat  CNTY_NBR   FIPS  \
# 0   78.0   Harris   4306          63 -95.397821  29.859671       102  48201
# 1   41.0   Dallas   2066          50 -96.777819  32.766537        57  48113
# 2  164.0  Tarrant   1093          34 -97.291165  32.771852       220  48439
# 3  169.0   Travis   1029          18 -97.781947  30.334233       227  48453
# 4   12.0    Bexar    918          37 -98.519663  29.448845        15  48029
#
#    Shape_Leng  Shape_Area          County Location
# 0    7.731110    0.422798  (-95.397821, 29.859671)
# 1    1.907782    0.226421  (-96.777819, 32.766537)
# 2    1.905740    0.225294  (-97.291165, 32.771852)
# 3    2.458272    0.248996  (-97.781947, 30.334233)
# 4    2.729791    0.302846  (-98.519663, 29.448845)

# %%
result = result[['County', 'Cases', 'Fatalities', 'lat', 'long']]
result
# Out:
#         County  Cases  Fatalities        lat        long
# 0       Harris   4306          63  29.859671  -95.397821
# 1       Dallas   2066          50  32.766537  -96.777819
# 2      Tarrant   1093          34  32.771852  -97.291165
# 3       Travis   1029          18  30.334233  -97.781947
# 4        Bexar    918          37  29.448845  -98.519663
# ..         ...    ...         ...        ...         ...
# 186   Hemphill      1           0  35.837502 -100.270463
# 187     Motley      1           0  34.074090 -100.779896
# 188  Gillespie      1           0  30.318002  -98.946272
# 189       Frio      1           0  28.867268  -99.108260
# 190     Zavala      1           0  28.865306  -99.761020
#
# [191 rows x 5 columns]

# %%
def df_to_geojson(df, properties, lat='lat', lon='long'):
    prefix = 'var' + ' data' + ' = '
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point','coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lat],row[lon]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols = ['County', 'Cases', 'Fatalities']
javascript_file = df_to_geojson(result, cols)
# {'type': 'FeatureCollection', 'features': [{'geometry': {'type': 'Point', 'coordinates': [-70.5867, -29.9953, 760]}, 'type': 'Feature', 'properties': {'name': 'A', 'description': 'Place a'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.4933, -30.1217, 1250]}, 'type': 'Feature', 'properties': {'name': 'B', 'description': 'Place b'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.5008, -30.0953, 1185]}, 'type': 'Feature', 'properties': {'name': 'C', 'description': 'Place c'}}]}

# %%
javascript_file
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'County': 'Harris', 'Cases': 4306, 'Fatalities': 63},
#    'geometry': {'type': 'Point', 'coordinates': [29.85967144, -95.39782106]}},
#   {'type': 'Feature',
#    'properties': {'County': '
 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.38623601, -95.67221685]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Wilbarger', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [34.08044953, -99.24089568]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Dickens', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.61663428, -100.7788138]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Armstrong', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [34.96522076, -101.3572412]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Dimmit', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.42161168, -99.760574]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Duval', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [27.68133382, -98.50889672]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Falls', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.25317017, -96.93579511]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Hansford', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [36.27753179, -101.3545624]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Franklin', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.17550691, -95.21841437]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Freestone', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.70486443, -96.14918535]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Mitchell', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.30636024, -100.9211128]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Mason', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.71742293, -99.2263026]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Madison', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.96564645, -95.92818441]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Red River', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.62074539, -95.0501886]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Roberts', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point',
#     'coordinates': [35.83855770000001, -100.8135689]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Sabine', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.34321941, -93.85170439]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Scurry', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.74720063, -100.9165071]}},
#   {'type': 'Feature',
#    'properties': {'County': 'La Salle', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.34621032, -99.1034773]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Knox', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.60614755, -99.74144313]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Stephens', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.73584155, -98.83612016]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Howard', 'Cases': 1, 'Fatalities': 1},
#    'geometry': {'type': 'Point',
#     'coordinates': [32.30610232, -101.43550970000001]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Hemphill', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [35.83750155, -100.2704628]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Motley', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point',
#     'coordinates': [34.07409017, -100.77989609999999]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Gillespie', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.31800246, -98.94627245]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Frio', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.86726774, -99.10826004]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Zavala', 'Cases': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.86530621, -99.76102001]}}]}

# %%
with open('static/js/map.json','w') as f:
    json.dump(javascript_file, f, indent=4, sort_keys=False)

# %%
browser.visit(url4)

# %%
headlines_harris = browser.html
headline_soup = bs(headlines_harris, 'html.parser')

# %%
# lis = headline_soup.find_all('li', class_="headline-list-with-abstract__item")
links = headline_soup.find_all('div', class_="headline-list-with-abstract__headline")

titles = []
hrefs = []

# %%
recent = headline_soup.find_all('div', class_="story-snapshot-with-abstract__headline")[0]

# %%
recent
# Out:
# <div class="story-snapshot-with-abstract__headline">
# <a class="story-snapshot-with-abstract__link" data-tracking="story-snapshot-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/houston-coronavirus-updates-news-and-cases/285-19aa1beb-554a-45a7-8d94-66f073e4cc56">
# <div class="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180" style="overflow-wrap: break-word;">
#                         Coronavirus updates: US reports more than 706K coronavirus cases, 59K recoveries
#                     </div>
# <div class="story-snapshot-with-abstract__mobile-title dot-ellipsis dot-height-135" style="overflow-wrap: break-word;">
#                         Coronavirus updates: US reports more than 706K coronavirus cases, 59K recoveries
#                     </div>
# </a>
# </div>

# %%
recent_title = recent.find('div', class_="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180").text.strip()
recent_title
# Out:
# 'Coronavirus updates: US reports more than 706K coronavirus cases, 59K recoveries'

# %%
titles.append(recent_title)
hrefs.append('https://www.khou.com' + recent.a['href'])

# %%
links
# Out:
# [<div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/navy-to-decide-fate-of-fired-uss-theodore-roosevelt-captain/285-60b83464-6483-45df-ae02-b7a3dd5ad950">
#                      US Navy to decide fate of fired USS Theodore Roosevelt captain
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-updates-live-blog-local-nationally-covid-houston-april-17/285-7d98c569-9bfd-418b-9779-5b15915dc523">
#                      Coronavirus updates: Montgomery County ends 'stay home, stop the spread' order, defers to Gov. Abbott's state order
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/senators-urge-anti-bias-police-training-over-mask-fears/285-cf93f69d-247c-45dc-b20e-60511cbe9c4a">
#                      Senators urge anti-bias police training over mask fears
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/gov-greg-abbott-economic-plan-timeline/285-a548f51a-1729-48ab-a63a-afeb8b4426ff">
#                      Back to business: Gov. Abbott lays out dates to re-open the state
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/local/gov-abbotts-move-to-keep-schools-closed-raises-questions-about-this-academic-year/285-680c3781-ea19-4dd9-851a-ad162ffca3ed">
#                      Gov. Abbott's move to keep schools closed raises questions about this academic year
#                  </a>
#  </div>, <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/covid-19-live-updates-april-17-2020/285-f0b03feb-50b0-43be-b4c6-ae69ae25f4a3">
#                      Trump pushes states to lift coronavirus restrictions, hopes to hold campaign rallies soon
#                  </a>
#  </div>]

# %%
for article in links:
    
    try:
        
        title = article.find('a', class_="headline-list-with-abstract__link").text
        
        link = article.a['href']
        
        if (title and link):
            
            
            print('-------------')
            print(title)
            print(link)
            titles.append(title.strip())
            hrefs.append('https://www.khou.com' + link)
            
    except:
        print('no')
# Out:
# -------------
#
#                     US Navy to decide fate of fired USS Theodore Roosevelt captain
#
# /article/news/health/coronavirus/navy-to-decide-fate-of-fired-uss-theodore-roosevelt-captain/285-60b83464-6483-45df-ae02-b7a3dd5ad950
# -------------
#
#                     Coronavirus updates: Montgomery County ends 'stay home, stop the spread' order, defers to Gov. Abbott's state order
#
# /article/news/health/coronavirus/coronavirus-updates-live-blog-local-nationally-covid-houston-april-17/285-7d98c569-9bfd-418b-9779-5b15915dc523
# -------------
#
#                     Senators urge anti-bias police training over mask fears
#
# /article/news/health/coronavirus/senators-urge-anti-bias-police-training-over-mask-fears/285-cf93f69d-247c-45dc-b20e-60511cbe9c4a
# -------------
#
#                     Back to business: Gov. Abbott lays out dates to re-open the state
#
# /article/news/health/coronavirus/gov-greg-abbott-economic-plan-timeline/285-a548f51a-1729-48ab-a63a-afeb8b4426ff
# -------------
#
#                     Gov. Abbott's move to keep schools closed raises questions about this academic year
#
# /article/news/local/gov-abbotts-move-to-keep-schools-closed-raises-questions-about-this-academic-year/285-680c3781-ea19-4dd9-851a-ad162ffca3ed
# -------------
#
#                     Trump pushes states to lift coronavirus restrictions, hopes to hold campaign rallies soon
#
# /article/news/health/coronavirus/covid-19-live-updates-april-17-2020/285-f0b03feb-50b0-43be-b4c6-ae69ae25f4a3

# %%
latest_headlines_df = pd.DataFrame(list(zip(titles, hrefs)), columns =['Headline', 'link'])

# %%
latest_headlines_df
# Out:
#                                             Headline  \
# 0  Coronavirus updates: US reports more than 706K...
# 1  US Navy to decide fate of fired USS Theodore R...
# 2  Coronavirus updates: Montgomery County ends 's...
# 3  Senators urge anti-bias police training over m...
# 4  Back to business: Gov. Abbott lays out dates t...
# 5  Gov. Abbott's move to keep schools closed rais...
# 6  Trump pushes states to lift coronavirus restri...
#
#                                                 link
# 0  https://www.khou.com/article/news/health/coron...
# 1  https://www.khou.com/article/news/health/coron...
# 2  https://www.khou.com/article/news/health/coron...
# 3  https://www.khou.com/article/news/health/coron...
# 4  https://www.khou.com/article/news/health/coron...
# 5  https://www.khou.com/article/news/local/gov-ab...
# 6  https://www.khou.com/article/news/health/coron...

# %%
latest_headlines_df.to_csv('static/csv/headlines.csv', index=False, header=True)

# %%
browser.quit()
