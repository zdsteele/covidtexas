# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from time import sleep
from datetime import datetime
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import time
import json
import os
import shutil

# %%
# Path to chromedriver.exe
executable_path = {'executable_path':'C:/Users/zacha/AppData/Local/bin/chromedriver.exe'}

# Open the Splinter Browswer
browser = Browser('chrome', **executable_path)

# %%
# URL to find information on Coronavirus
url1 = "https://txdshs.maps.arcgis.com/apps/opsdashboard/index.html#/ed483ecd702b4298ab01e8b9cafc8b83"

url2 = "https://dshs.texas.gov/coronavirus/"

url3 = "http://publichealth.harriscountytx.gov/Resources/2019-Novel-Coronavirus/Harris-County-COVID-19-Confirmed-Cases"

url4 = "https://www.khou.com/section/news/health/coronavirus"

# %%
# Visiting the url 
browser.visit(url1)

# %%
time.sleep(7)# Creating the Beautiful soup for URL
html = browser.html
soup = bs(html, 'html.parser')

# %%
# All the Texas counties
# counties = soup.find('nav', attrs={'class':'feature-list'})

# getting all the spans with the information for each Texas county
# rows = counties.find_all('span')

# %%
# counter = 0

# county = []
# cases = []

# for row in rows:
#     try:
#         print(rows[counter].text.strip().split('\n'))
#         county.append(rows[counter].text.strip().split('\n')[0])
#         cases.append(rows[counter].text.strip().split('\n')[1])
#         counter = counter + 3
        
#     except:
#         print('failure')

# %%
# df = pd.DataFrame(list(zip(county, cases)), columns =['Texas_County', 'COVID_19_Cases'])
# df

# %%
# Droping the word 'County'
# df['Texas_County'] = df['Texas_County'].apply(lambda x : x.split(' County')[0])

# %%
# Revise? 
reported_cases = soup.find_all('text')[6].text
reported_cases
# Out:
# '6,110'

# %%
deaths = soup.find_all('text')[8].text
deaths
# Out:
# '105'

# %%
df_stats = pd.DataFrame({'Cases':[reported_cases], 'Deaths':[deaths]})
df_stats.to_csv('static/csv/stats.csv', index=False)

# %%
# Getting Total Cases and Deaths 
browser.visit(url2)

# %%
browser.find_by_text('Accessible version').click()
time.sleep(5)

# %%
source = 'C:/Users/zacha/Downloads/'
destination = 'C:/Users/zacha/Documents/COVID-19/'
filename = 'CaseCountData.xlsx'

# %%
shutil.move(os.path.join(source, filename), os.path.join(destination, filename))
# Out:
# 'C:/Users/zacha/Documents/COVID-19/CaseCountData.xlsx'

# %%
# dest = shutil.move(source, destination, )

# %%
df = pd.read_excel('CaseCountData.xlsx', header=1).dropna()
df.sort_values(by=['Positive'], ascending=False, inplace=True)
df['County'] = df.apply(lambda x: x['County'].rstrip(), axis=1)
df
# Out:
#        No.       County  Positive  Fatalities
# 58    59.0       Harris      1106          13
# 30    31.0       Dallas       921          17
# 131  132.0       Travis       430           4
# 126  127.0      Tarrant       383           7
# 7      8.0        Bexar       342           9
# ..     ...          ...       ...         ...
# 129  130.0        Titus         1           0
# 1      2.0      Andrews         1           0
# 125  126.0      Swisher         1           0
# 120  121.0  San Jacinto         1           0
# 0      1.0     Anderson         1           0
#
# [151 rows x 4 columns]

# %%
browser.visit(url3)

# %%
harris_table = browser.find_by_id('covidtable')

# %%
html_harris = browser.html
harris_soup = bs(html_harris, 'html.parser')

# %%
harris_data = []
table = harris_soup.find('table', attrs={'id':'covidtable'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    harris_data.append([ele for ele in cols if ele]) # Get rid of empty values

# %%
columns = ['Patient', 'Sex', 'Age_Range', 'Location','Exposure', 'Status']

# %%
harris_data = harris_data[1:]

# %%
harris_df = pd.DataFrame(harris_data, columns=columns)

# %%
harris_df.sort_values(by=['Age_Range'], inplace=True)

# %%
harris_df
# Out:
#     Patient     Sex Age_Range Location                   Exposure    Status
# 43       44    Male     0 - 9       NW  Possible Exposure to Case    Active
# 45       46  Female     0 - 9       NW  Possible Exposure to Case    Active
# 172     173  Female     0 - 9       NW  Possible Exposure to Case    Active
# 185     186  Female     0 - 9       SE  Possible Exposure to Case    Active
# 147     148    Male   10 - 19       SE  Possible Exposure to Case    Active
# ..      ...     ...       ...      ...                        ...       ...
# 154     155  Female       80+       SE      Investigation Pending    Active
# 246     247  Female       80+       SW      Investigation Pending    Active
# 15       16    Male       80+       NW          No Known Exposure  Deceased
# 158     159  Female       80+       NW          History of Travel    Active
# 193     194  Female       80+       SE          No Known Exposure    Active
#
# [254 rows x 6 columns]

# %%
harris_df.to_csv('static/csv/harris_stats.csv', index=False, header=True)

# %%
harris_df.head()
# Out:
#     Patient     Sex Age_Range Location                   Exposure  Status
# 43       44    Male     0 - 9       NW  Possible Exposure to Case  Active
# 45       46  Female     0 - 9       NW  Possible Exposure to Case  Active
# 172     173  Female     0 - 9       NW  Possible Exposure to Case  Active
# 185     186  Female     0 - 9       SE  Possible Exposure to Case  Active
# 147     148    Male   10 - 19       SE  Possible Exposure to Case  Active

# %%
All_Tex_Counties_df = pd.read_csv('static/csv/Texas_Counties.csv')
All_Tex_Counties_df.head()
# Out:
#      X (Lat)   Y (Long)    CNTY_NM  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# 0 -97.492799  29.456415   Gonzales        90  48177    2.124911    0.257805
# 1 -98.697292  27.043405   Jim Hogg       125  48247    2.271751    0.267624
# 2 -97.681378  26.924094     Kenedy        66  48261    5.067864    0.389397
# 3 -96.965687  30.310651        Lee       144  48287    2.213853    0.153990
# 4 -95.853568  32.211881  Henderson       108  48213    3.152909    0.235056
#
#            County Location
# 0  (-97.492799, 29.456415)
# 1  (-98.697292, 27.043405)
# 2  (-97.681378, 26.924094)
# 3  (-96.965687, 30.310651)
# 4  (-95.853568, 32.211881)

# %%
All_Tex_Counties = All_Tex_Counties_df['CNTY_NM'].tolist()

# %%
df_counties = df['County'].tolist()

# %%
Counties_with_Cases = []

for i in df_counties:
    
    if i.rstrip() in All_Tex_Counties:
        Counties_with_Cases.append(i.rstrip())
        print(f'{i}---found')
        
    elif i == 'DeWitt':
        Counties_with_Cases.append('De Witt')
        print(f'{i}---found')
    else:
        print(f'Houston we have a problem: {i}')
# Out:
# Harris---found
# Dallas---found
# Travis---found
# Tarrant---found
# Bexar---found
# Denton---found
# Collin---found
# Fort Bend---found
# Lubbock---found
# Galveston---found
# Brazoria---found
# Montgomery---found
# El Paso---found
# Hidalgo---found
# Webb---found
# Brazos---found
# Williamson---found
# Cameron---found
# Smith---found
# Bell---found
# McLennan---found
# Nueces---found
# Hays---found
# Wichita---found
# Matagorda---found
# Victoria---found
# Ellis---found
# Jefferson---found
# Guadalupe---found
# Randall---found
# Potter---found
# Taylor---found
# Midland---found
# Ector---found
# Johnson---found
# Comal---found
# Bowie---found
# Washington---found
# Tom Green---found
# Nacogdoches---found
# Hardin---found
# Gregg---found
# Orange---found
# Grayson---found
# Rusk---found
# Rockwall---found
# Shelby---found
# Chambers---found
# Fayette---found
# Kaufman---found
# Castro---found
# Angelina---found
# Hood---found
# Wharton---found
# Kendall---found
# Waller---found
# Hunt---found
# Calhoun---found
# Walker---found
# Polk---found
# Hockley---found
# Erath---found
# Bastrop---found
# Moore---found
# Wilson---found
# Parker---found
# DeWitt---found
# Hale---found
# Starr---found
# Liberty---found
# Lamar---found
# Harrison---found
# Donley---found
# Cherokee---found
# Navarro---found
# Gray---found
# Val Verde---found
# Willacy---found
# Hill---found
# Deaf Smith---found
# Terry---found
# Maverick---found
# Panola---found
# Coryell---found
# San Patricio---found
# Cass---found
# San Augustine---found
# Austin---found
# Uvalde---found
# Burnet---found
# Brown---found
# Van Zandt---found
# Medina---found
# Young---found
# Lynn---found
# Llano---found
# Live Oak---found
# Limestone---found
# Jackson---found
# Hopkins---found
# Upshur---found
# Eastland---found
# Dawson---found
# Caldwell---found
# Wise---found
# Grimes---found
# Robertson---found
# Trinity---found
# Karnes---found
# Oldham---found
# Kleberg---found
# Atascosa---found
# Blanco---found
# Burleson---found
# Colorado---found
# Crane---found
# Fannin---found
# Gillespie---found
# Jasper---found
# Jim Wells---found
# Kerr---found
# Hutchinson---found
# Leon---found
# Lavaca---found
# Lee---found
# Milam---found
# Franklin---found
# Wood---found
# Newton---found
# Morris---found
# Montague---found
# Camp---found
# Clay---found
# Comanche---found
# Mason---found
# Falls---found
# Martin---found
# Lamb---found
# Gaines---found
# Lampasas---found
# Goliad---found
# Gonzales---found
# Tyler---found
# Hemphill---found
# Henderson---found
# Palo Pinto---found
# Titus---found
# Andrews---found
# Swisher---found
# San Jacinto---found
# Anderson---found

# %%
All_Tex_Counties_df = All_Tex_Counties_df.set_index('CNTY_NM')

# %%
Geo_df = All_Tex_Counties_df.loc[Counties_with_Cases]
Geo_df.head()
# Out:
#            X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  Shape_Area  \
# CNTY_NM
# Harris  -95.397821  29.859671       102  48201    7.731110    0.422798
# Dallas  -96.777819  32.766537        57  48113    1.907782    0.226421
# Travis  -97.781947  30.334233       227  48453    2.458272    0.248996
# Tarrant -97.291165  32.771852       220  48439    1.905740    0.225294
# Bexar   -98.519663  29.448845        15  48029    2.729791    0.302846
#
#                  County Location
# CNTY_NM
# Harris   (-95.397821, 29.859671)
# Dallas   (-96.777819, 32.766537)
# Travis   (-97.781947, 30.334233)
# Tarrant  (-97.291165, 32.771852)
# Bexar    (-98.519663, 29.448845)

# %%
Geo_df = Geo_df.reset_index()
Geo_df = Geo_df.rename(columns={"CNTY_NM": "County"})
Geo_df
# Out:
#           County     X (Lat)   Y (Long)  CNTY_NBR   FIPS  Shape_Leng  \
# 0         Harris  -95.397821  29.859671       102  48201    7.731110
# 1         Dallas  -96.777819  32.766537        57  48113    1.907782
# 2         Travis  -97.781947  30.334233       227  48453    2.458272
# 3        Tarrant  -97.291165  32.771852       220  48439    1.905740
# 4          Bexar  -98.519663  29.448845        15  48029    2.729791
# ..           ...         ...        ...       ...    ...         ...
# 146        Titus  -94.965098  33.216091       225  48449    2.003081
# 147      Andrews -102.637884  32.305063         2  48003    2.579602
# 148      Swisher -101.734951  34.530650       219  48437    1.924577
# 149  San Jacinto  -95.166833  30.579489       204  48407    2.203357
# 150     Anderson  -95.652518  31.813215         1  48001    3.709381
#
#      Shape_Area           County Location
# 0      0.422798   (-95.397821, 29.859671)
# 1      0.226421   (-96.777819, 32.766537)
# 2      0.248996   (-97.781947, 30.334233)
# 3      0.225294   (-97.291165, 32.771852)
# 4      0.302846   (-98.519663, 29.448845)
# ..          ...                       ...
# 146    0.106914   (-94.965098, 33.216091)
# 147    0.372269  (-102.637884, 32.305063)
# 148    0.229376   (-101.734951, 34.53065)
# 149    0.153019   (-95.166833, 30.579489)
# 150    0.265992   (-95.652518, 31.813215)
#
# [151 rows x 8 columns]

# %%
result = pd.merge(df, Geo_df, on='County')
result = result.rename(columns={'X (Lat)':'long', 'Y (Long)':'lat'})

result.head()
# Out:
#      No.   County  Positive  Fatalities       long        lat  CNTY_NBR  \
# 0   59.0   Harris      1106          13 -95.397821  29.859671       102
# 1   31.0   Dallas       921          17 -96.777819  32.766537        57
# 2  132.0   Travis       430           4 -97.781947  30.334233       227
# 3  127.0  Tarrant       383           7 -97.291165  32.771852       220
# 4    8.0    Bexar       342           9 -98.519663  29.448845        15
#
#     FIPS  Shape_Leng  Shape_Area          County Location
# 0  48201    7.731110    0.422798  (-95.397821, 29.859671)
# 1  48113    1.907782    0.226421  (-96.777819, 32.766537)
# 2  48453    2.458272    0.248996  (-97.781947, 30.334233)
# 3  48439    1.905740    0.225294  (-97.291165, 32.771852)
# 4  48029    2.729791    0.302846  (-98.519663, 29.448845)

# %%
result = result[['County', 'Positive', 'Fatalities', 'lat', 'long']]
result
# Out:
#           County  Positive  Fatalities        lat        long
# 0         Harris      1106          13  29.859671  -95.397821
# 1         Dallas       921          17  32.766537  -96.777819
# 2         Travis       430           4  30.334233  -97.781947
# 3        Tarrant       383           7  32.771852  -97.291165
# 4          Bexar       342           9  29.448845  -98.519663
# ..           ...       ...         ...        ...         ...
# 145        Titus         1           0  33.216091  -94.965098
# 146      Andrews         1           0  32.305063 -102.637884
# 147      Swisher         1           0  34.530650 -101.734951
# 148  San Jacinto         1           0  30.579489  -95.166833
# 149     Anderson         1           0  31.813215  -95.652518
#
# [150 rows x 5 columns]

# %%
def df_to_geojson(df, properties, lat='lat', lon='long'):
    prefix = 'var' + ' data' + ' = '
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point','coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lat],row[lon]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols = ['County', 'Positive', 'Fatalities']
javascript_file = df_to_geojson(result, cols)
# {'type': 'FeatureCollection', 'features': [{'geometry': {'type': 'Point', 'coordinates': [-70.5867, -29.9953, 760]}, 'type': 'Feature', 'properties': {'name': 'A', 'description': 'Place a'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.4933, -30.1217, 1250]}, 'type': 'Feature', 'properties': {'name': 'B', 'description': 'Place b'}}, {'geometry': {'type': 'Point', 'coordinates': [-70.5008, -30.0953, 1185]}, 'type': 'Feature', 'properties': {'name': 'C', 'description': 'Place c'}}]}

# %%
javascript_file
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'County': 'Harris', 'Positive': 1106, 'Fatalities': 13},
#    'geometry': {'type': 'Point', 'coordinates': [29.85967144, -95.39782106]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Dallas', 'Positive': 921, 'Fatalities': 17},
#    'geometry': {'type': 'Point', 'coordinates': [32.76653746, -96.77781862]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Travis', 'Positive': 430, 'Fatalities': 4},
#    'geometry': {'type': 'Point', 'coordinates': [30.33423319, -97.78194654]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Tarrant', 'Positive': 383, 'Fatalities': 7},
#    'geometry': {'type': 'Point', 'coordinates': [32.77185236, -97.29116473]}},
#   {'type': 'Feature',
#    'properties': {'County': '
}},
#   {'type': 'Feature',
#    'properties': {'County': 'Franklin', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.17550691, -95.21841437]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Wood', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.78634374, -95.38206498]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Newton', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.78619977, -93.74462993]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Morris', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.11368507, -94.73205137]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Montague', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.67496328, -97.72466993]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Camp', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.97321771, -94.97860185]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Clay', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.78379717, -98.208958]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Comanche', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.9490639, -98.55841538]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Mason', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.71742293, -99.2263026]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Falls', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.25317017, -96.93579511]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Martin', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.30605847, -101.9512464]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Lamb', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [34.06861242, -102.3517095]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Gaines', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.74074537, -102.6351246]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Lampasas', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.19627791, -98.24142711]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Goliad', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [28.65708563, -97.42646082]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Gonzales', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [29.45641495, -97.49279927]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Tyler', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.7712607, -94.37651432]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Hemphill', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [35.83750155, -100.2704628]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Henderson', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point',
#     'coordinates': [32.21188078, -95.85356847000001]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Palo Pinto', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.75316856, -98.31299522]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Titus', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [33.2160906, -94.96509786]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Andrews', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [32.30506283, -102.6378839]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Swisher', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [34.53064989, -101.734951]}},
#   {'type': 'Feature',
#    'properties': {'County': 'San Jacinto', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [30.57948905, -95.16683273]}},
#   {'type': 'Feature',
#    'properties': {'County': 'Anderson', 'Positive': 1, 'Fatalities': 0},
#    'geometry': {'type': 'Point', 'coordinates': [31.81321543, -95.65251774]}}]}

# %%
with open('static/js/map.json','w') as f:
    json.dump(javascript_file, f, indent=4, sort_keys=False)

# %%
browser.visit(url4)

# %%
headlines_harris = browser.html
headline_soup = bs(headlines_harris, 'html.parser')

# %%
# lis = headline_soup.find_all('li', class_="headline-list-with-abstract__item")
links = headline_soup.find_all('div', class_="headline-list-with-abstract__headline")

titles = []
hrefs = []

# %%
recent = headline_soup.find_all('div', class_="story-snapshot-with-abstract__headline")[0]

# %%
recent
# Out:
# <div class="story-snapshot-with-abstract__headline">
# <a class="story-snapshot-with-abstract__link" data-tracking="story-snapshot-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-austin-cases-of-covid-19-confirmed/285-e7770e57-cf62-4571-a97c-b10216c50cd0">
# <div class="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180" style="overflow-wrap: break-word;">
#                         Galveston County woman among 2 positive cases of coronavirus confirmed in Austin area
#                     </div>
# <div class="story-snapshot-with-abstract__mobile-title dot-ellipsis dot-height-135" style="overflow-wrap: break-word;">
#                         Galveston County woman among 2 positive cases of coronavirus confirmed in Austin area
#                     </div>
# </a>
# </div>

# %%
recent_title = recent.find('div', class_="story-snapshot-with-abstract__desktop-title dot-ellipsis dot-height-180").text.strip()
recent_title
# Out:
# 'Galveston County woman among 2 positive cases of coronavirus confirmed in Austin area'

# %%
titles.append(recent_title)
hrefs.append('https://www.khou.com' + recent.a['href'])

# %%
links
# Out:
# [<div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-updates-houston-live-blog-april-3/285-6d1d2743-5612-4773-8627-3b9622f845d8">
#                      Coronavirus updates: Over 80 people test positive at Texas City nursing home
#                  </a>
#  </div>,
#  <div class="headline-list-with-abstract__headline"> <a class="headline-list-with-abstract__link">2020: Simple Method Ends Toenail Fungus - Try It Now!</a> </div>,
#  <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/new-york-gets-chinese-ventilators/285-4d4f73e9-3274-4a9a-88cf-096a7e0a3c3b">
#                      New York gets Chinese ventilators; Trump wants more thanks
#                  </a>
#  </div>,
#  <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-houston-impacts-on-undocumented-immigrants/285-085f2467-5e43-433d-bd85-053732b581d0">
#                      Coronavirus impact on local undocumented immigrants unknown
#                  </a>
#  </div>,
#  <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/trump-believes-nfl-season-will-start-on-time-in-meeting-with-sports-commissioners/285-f10ac0a1-cc35-4885-9f60-9270e6b88fa2">
#                      Trump says he believes NFL season will start on time in meeting with sports commissioners
#                  </a>
#  </div>,
#  <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/coronavirus-updates-houston-blog-live-april-4/285-f799b57f-cb53-47c7-80a4-06c894d89baf">
#                      Coronavirus updates: Galveston County reports first death due to COVID-19
#                  </a>
#  </div>,
#  <div class="headline-list-with-abstract__headline">
#  <a class="headline-list-with-abstract__link" data-tracking="headline-list-with-abstract/headlineLinkClicked" href="/article/news/health/coronavirus/another-cruise-ship-with-2-virus-deaths-docks-in-florida/285-56817885-0283-4715-8708-b6f72e4892d2">
#                      Another cruise ship with virus victims docks in Florida
#                  </a>
#  </div>]

# %%
for article in links:
    
    try:
        
        title = article.find('a', class_="headline-list-with-abstract__link").text
        
        link = article.a['href']
        
        if (title and link):
            
            
            print('-------------')
            print(title)
            print(link)
            titles.append(title.strip())
            hrefs.append('https://www.khou.com' + link)
            
    except:
        print('no')
# Out:
# -------------
#
#                     Coronavirus updates: Over 80 people test positive at Texas City nursing home
#
# /article/news/health/coronavirus/coronavirus-updates-houston-live-blog-april-3/285-6d1d2743-5612-4773-8627-3b9622f845d8
# no
# -------------
#
#                     New York gets Chinese ventilators; Trump wants more thanks
#
# /article/news/health/coronavirus/new-york-gets-chinese-ventilators/285-4d4f73e9-3274-4a9a-88cf-096a7e0a3c3b
# -------------
#
#                     Coronavirus impact on local undocumented immigrants unknown
#
# /article/news/health/coronavirus/coronavirus-houston-impacts-on-undocumented-immigrants/285-085f2467-5e43-433d-bd85-053732b581d0
# -------------
#
#                     Trump says he believes NFL season will start on time in meeting with sports commissioners
#
# /article/news/health/coronavirus/trump-believes-nfl-season-will-start-on-time-in-meeting-with-sports-commissioners/285-f10ac0a1-cc35-4885-9f60-9270e6b88fa2
# -------------
#
#                     Coronavirus updates: Galveston County reports first death due to COVID-19
#
# /article/news/health/coronavirus/coronavirus-updates-houston-blog-live-april-4/285-f799b57f-cb53-47c7-80a4-06c894d89baf
# -------------
#
#                     Another cruise ship with virus victims docks in Florida
#
# /article/news/health/coronavirus/another-cruise-ship-with-2-virus-deaths-docks-in-florida/285-56817885-0283-4715-8708-b6f72e4892d2

# %%
latest_headlines_df = pd.DataFrame(list(zip(titles, hrefs)), columns =['Headline', 'link'])

# %%
latest_headlines_df
# Out:
#                                             Headline  \
# 0  Galveston County woman among 2 positive cases ...
# 1  Coronavirus updates: Over 80 people test posit...
# 2  New York gets Chinese ventilators; Trump wants...
# 3  Coronavirus impact on local undocumented immig...
# 4  Trump says he believes NFL season will start o...
# 5  Coronavirus updates: Galveston County reports ...
# 6  Another cruise ship with virus victims docks i...
#
#                                                 link
# 0  https://www.khou.com/article/news/health/coron...
# 1  https://www.khou.com/article/news/health/coron...
# 2  https://www.khou.com/article/news/health/coron...
# 3  https://www.khou.com/article/news/health/coron...
# 4  https://www.khou.com/article/news/health/coron...
# 5  https://www.khou.com/article/news/health/coron...
# 6  https://www.khou.com/article/news/health/coron...

# %%
latest_headlines_df.to_csv('static/csv/headlines.csv', index=False, header=True)

# %%
browser.quit()
