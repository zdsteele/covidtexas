# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('static/csv/CaseCountData.csv')
df
# Out:
#        No.       County  Positive  Fatalities
# 0     59.0       Harris      1106          13
# 1     31.0       Dallas       921          17
# 2    132.0       Travis       430           4
# 3    127.0      Tarrant       383           7
# 4      8.0        Bexar       342           9
# ..     ...          ...       ...         ...
# 146  130.0        Titus         1           0
# 147    2.0      Andrews         1           0
# 148  126.0      Swisher         1           0
# 149  121.0  San Jacinto         1           0
# 150    1.0     Anderson         1           0
#
# [151 rows x 4 columns]

# %%
df = df[['County', 'Positive', 'Fatalities']]

# %%
df
# Out:
#           County  Positive  Fatalities
# 0         Harris      1106          13
# 1         Dallas       921          17
# 2         Travis       430           4
# 3        Tarrant       383           7
# 4          Bexar       342           9
# ..           ...       ...         ...
# 146        Titus         1           0
# 147      Andrews         1           0
# 148      Swisher         1           0
# 149  San Jacinto         1           0
# 150     Anderson         1           0
#
# [151 rows x 3 columns]

# %%
df.to_dict()
# Out:
# {'County': {0: 'Harris',
#   1: 'Dallas',
#   2: 'Travis',
#   3: 'Tarrant',
#   4: 'Bexar',
#   5: 'Denton',
#   6: 'Collin',
#   7: 'Fort Bend',
#   8: 'Lubbock',
#   9: 'Galveston',
#   10: 'Brazoria',
#   11: 'Montgomery',
#   12: 'El Paso',
#   13: 'Hidalgo',
#   14: 'Webb',
#   15: 'Brazos',
#   16: 'Williamson',
#   17: 'Cameron',
#   18: 'Smith',
#   19: 'Bell',
#   20: 'McLennan',
#   21: 'Nueces',
#   22: 'Hays',
#   23: 'Wichita',
#   24: 'Matagorda',
#   25: 'Victoria',
#   26: 'Ellis',
#   27: 'Jefferson',
#   28: 'Guadalupe',
#   29: 'Randall',
#   30: 'Potter',
#   31: 'Taylor',
#   32: 'Midland',
#   33: 'Ector',
#   34: 'Johnson',
#   35: 'Comal',
#   36: 'Bowie',
#   37: 'Washington',
#   38: 'Tom Green',
#   39: 'Nacogdoches',
#   40: 'Hardin',
#   41: 'Gregg',
#   42: 'Orange',
#   43: 'Grayson',
#   44: 'Rusk',
#   45: 'Rockwall',
#   46: 'Shelby',
#   47: 'Chambers',
#   48: 'Fayette',
#   49: 'Kaufman',
#   50: 'Castro',
#   51: 'Angelina',
#   52: 'Hood',
# ...
